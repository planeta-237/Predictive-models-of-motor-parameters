# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from sklearn.model_selection import TimeSeriesSplit
from scipy.optimize import minimize
from statsmodels.tsa.ar_model import AR
import pmdarima as pm
from pmdarima.model_selection import train_test_split
import statsmodels.api as sm
from hmmlearn.hmm import GaussianHMM
import xgboost as xgb
from catboost import CatBoostRegressor
import lightgbm as lgb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from fbprophet import Prophet
m = Prophet()

from gluonts.dataset.common import ListDataset
from gluonts.model.deepar import DeepAREstimator
from gluonts.trainer import Trainer
from gluonts.dataset.util import to_pandas
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import Evaluator

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, TimeSeriesSplit
scaler = StandardScaler()

from itertools import product
from tqdm import tqdm_notebook

import warnings                                  
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Quality metrics

# %%
from sklearn.metrics import explained_variance_score, max_error, mean_absolute_error, mean_squared_error, mean_squared_log_error, median_absolute_error, r2_score,  mean_poisson_deviance
def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def quality_metrics(actual, preds):
    
    mape = mean_absolute_percentage_error(actual, preds)
    evs = explained_variance_score(actual, preds)
    maxerror = max_error(actual, preds)
    mae = mean_absolute_error(actual, preds)
    mse = mean_squared_error(actual, preds)
    msle = mean_squared_log_error(actual, preds)
    r2 = r2_score(actual, preds)
    mpd = mean_poisson_deviance(actual, preds)
    
    return mape, evs, maxerror, mae, mse, msle, r2, mpd

# %%
def timeseries_train_test_split(X, y, test_size):
    """
        Perform train-test split with respect to time series structure
    """
    
    # get the index after which test set starts
    test_index = int(len(X)*(1-test_size))
    
    X_train = X.iloc[:test_index-1]
    y_train = y.iloc[:test_index-1]
    X_test = X.iloc[test_index:]
    y_test = y.iloc[test_index:]
    
    return X_train, X_test, y_train, y_test

# %%
def split(data, size=0.3):
    
    train, test = data[0:len(data)-round(len(data)*size)], data[len(data)-round(len(data)*size):]
    
    return train, test

# %% [markdown]
# ### Data preparation

# %%
def format_data(data, column_name, start_drop=86401, end_drop=1048503):
    
    """
        data - dataset with timeseries
        column_name - Motor parameter name
        start_drop - reference point for deleting data from the source dataset
        end_drop - the endpoint for deleting data from the source dataset
    """
    
    data = pd.read_csv(data, header=None)
    data.drop(data.columns[[1,3,4]], axis=1, inplace=True)
    data.columns = ['datetime', column_name]
    data_ = pd.to_datetime(data['datetime'])
    data__ = pd.DataFrame(data[column_name].values, index=data_, columns=[column_name])
    data__.drop(data__.index[start_drop:end_drop], inplace=True)
    data__ = data__.resample('T').ffill()
    
    return data__

# %%
def plotModel(actual_1, actual_2, actual_3, actual_4, model_1, 
                model_2, model_3, model_4, name_model, 
                sd_mse=None, sd_mape=None, sd_maxerror=None, cu_mse=None, 
                cu_mape=None, cu_maxerror=None, te_mse=None, te_mape=None, 
                te_maxerror=None, nm_mse=None, nm_mape=None, nm_maxerror=None, 
                predictive_mode=False):
    """
        actual - actual motor parameter values
        model - predicted motor parameter values
    """
    with plt.style.context('seaborn-white'):

        f, axs = plt.subplots(2,2,figsize=(20,10))
        
        ax1 = plt.subplot(221)
        ax1.set_ylabel('Motor speed (M/MN)', fontsize=15)
        ax1.plot(model_1, linewidth=2, color='red', label='Model')
        ax1.plot(actual_1, linewidth=2, color='blue', label='Actual')
        ax1.legend(['Model', 'Actual'])
        ax1.grid(True)
                                                                 
        ax2 = plt.subplot(222)
        ax2.set_ylabel('Motor current (А)', fontsize=15)
        ax2.plot(model_2, linewidth=2, color='red', label='Model')
        ax2.plot(actual_2, linewidth=0.5, color='blue', label='Actual')
        ax2.legend(['Model', 'Actual'])
        ax2.grid(True)

        ax3 = plt.subplot(223)
        ax3.set_ylabel('Motor temperature (°C)', fontsize=15)
        ax3.plot(model_3, linewidth=2, color='red', label='Model')
        ax3.set_xlabel('Time (h)', fontsize=15)
        ax3.plot(actual_3, linewidth=0.5, color='blue', label='Actual')
        ax3.legend(['Model', 'Actual'])
        ax3.grid(True)

        ax4 = plt.subplot(224)
        ax4.set_ylabel('Motor torque (Nm)', fontsize=15)
        ax4.set_xlabel('Time (h)', fontsize=15)
        ax4.plot(model_4, linewidth=2, color='red', label='Model')
        ax4.plot(actual_4, linewidth=0.5, color='blue', label='Actual')
        ax4.legend(['Model', 'Actual'])
        ax4.grid(True)
              
        if predictive_mode:
            
            ax1.set_title(f'Motor speed ({name_model})\n MSE: {sd_mse:.{2}f},'
                            f'MAPE: {sd_mape:.{2}f}, MAX_ERROR: {sd_maxerror:.{2}f}', fontsize=15)
            ax1.vlines(model_1[0:1].index, ymin=410, ymax=440, linestyles='dashed')
            ax1.axvspan(model_1[0:1].index, actual_1[len(actual_1)-1:].index, alpha=0.3, color='lightgrey')                                                  
            
            ax2.set_title(f'Motor current ({name_model})\n MSE: {cu_mse:.{2}f},'
                            f'MAPE: {cu_mape:.{2}f}, MAX_ERROR: {cu_maxerror:.{2}f}', fontsize=15)
            ax2.vlines(model_2[0:1].index, ymin=115, ymax=125, linestyles='dashed')
            ax2.axvspan(model_2[0:1].index, actual_2[len(actual_2)-1:].index, alpha=0.3, color='lightgrey')
            
            ax3.set_title(f'Motor temperature ({name_model})\n MSE: {te_mse:.{2}f},'
                            f'MAPE: {te_mape:.{2}f}, MAX_ERROR: {te_maxerror:.{2}f}', fontsize=15)
            ax3.vlines(model_3[0:1].index, ymin=40, ymax=45, linestyles='dashed')
            ax3.axvspan(model_3[0:1].index, actual_3[len(actual_3)-1:].index, alpha=0.3, color='lightgrey')
            
            ax4.set_title(f'Motor torque ({name_model})\n MSE: {nm_mse:.{2}f},'
                        f'MAPE: {nm_mape:.{2}f}, MAX_ERROR: {nm_maxerror:.{2}f}', fontsize=15)
            ax4.vlines(model_4[0:1].index, ymin=278, ymax=298, linestyles='dashed')
            ax4.axvspan(model_4[0:1].index, actual_4[len(actual_4)-1:].index, alpha=0.3, color='lightgrey')

        else:
                                                                 
            ax1.set_title(f'Motor speed ({name_model})', fontsize=15)
            ax2.set_title(f'Motor current ({name_model})', fontsize=15)
            ax3.set_title(f'Motor temperature ({name_model})', fontsize=15)
            ax4.set_title(f'Motor torque ({name_model})', fontsize=15)
                                                             
        plt.show()

# %%
data_ts_sd_m = format_data('datasets/AI_M061202_SD.csv', 'Motor speed')
data_ts_cu_m = format_data('datasets/AI_M061202_CU.csv', 'Current')
data_ts_te_m = format_data('datasets/AI_M061202_MOT_TE.csv', 'Temperature')
data_ts_nm_m = format_data('datasets/AI_M061202_Nm.csv', 'Torque')

# %%
with plt.style.context('seaborn-deep'):
    
    f, axs = plt.subplots(2,2,figsize=(20,10))

    ax1 = plt.subplot(221)
    ax1.set_ylabel('Motor speed (M/MN)', fontsize=15)
    ax1.plot(data_ts_sd_m, linewidth=2, color='orange')
    ax1.set_title('Change in motor speed during the day', fontsize=15)

    ax2 = plt.subplot(222)
    ax2.set_ylabel('Motor current (А)', fontsize=15)
    ax2.plot(data_ts_cu_m, linewidth=1, color='blue')
    ax2.set_title('Change in motor current during the day', fontsize=15)
    
    ax3 = plt.subplot(223)
    ax3.set_ylabel('Motor temperature (°C)', fontsize=15)
    ax3.plot(data_ts_te_m, linewidth=1, color='red')
    ax3.set_title('Change in motor temperature during the day', fontsize=15)
    
    ax4 = plt.subplot(224)
    ax4.set_ylabel('Motor torque (Nm)', fontsize=15)
    ax4.plot(data_ts_nm_m, linewidth=1, color='purple')
    ax4.set_title('Change in motor torque during the day', fontsize=15)
    
    ax1.grid(True)
    ax2.grid(True)
    ax3.grid(True)
    ax4.grid(True)
    plt.show()

# %% [markdown]
# ### Moving average

# %%
def moving_average(series, n):
    """
        Calculate average of last n observations
    """
    return np.average(series[-n:])

print(f"Rolling mean (motor speed): {moving_average(data_ts_sd_m, 1441)}\n"
      f"Rolling mean (motor current): {moving_average(data_ts_cu_m, 1441)}\n" 
      f"Rolling mean (motor temperature): {moving_average(data_ts_te_m, 1441)}\n" 
      f"Rolling mean (motor torque): {moving_average(data_ts_nm_m, 1441)}")
# Out:
# Rolling mean (motor speed): 427.3448993754337
# Rolling mean (motor current): 119.29562803608606
# Rolling mean (motor temperature): 42.05204718945177
# Rolling mean (motor torque): 285.381679389313

# %%
rolling_mean_sd = data_ts_sd_m.rolling(window=50).mean()
rolling_mean_cu = data_ts_cu_m.rolling(window=50).mean()
rolling_mean_te = data_ts_te_m.rolling(window=50).mean()
rolling_mean_nm = data_ts_nm_m.rolling(window=50).mean()

# %%
plotModel(data_ts_sd_m['Motor speed'], 
            data_ts_cu_m['Current'], 
            data_ts_te_m['Temperature'], 
            data_ts_nm_m['Torque'], 
            rolling_mean_sd, 
            rolling_mean_cu, 
            rolling_mean_te, 
            rolling_mean_nm, 
            'MA', predictive_mode=False)

# %% [markdown]
# ### Weighted moving average

# %%
def weighted_average(series, weights):
    """
        Calculate weighter average on series
    """
    result = 0.0
    weights.reverse()
    for n in range(len(weights)):
        result += series.iloc[-n-1] * weights[n]
    return float(result)

print(f"weighter average (motor speed): {weighted_average(data_ts_sd_m, [0.6, 0.3, 0.1])}\n"
      f"weighter average (motor current): {weighted_average(data_ts_cu_m, [0.6, 0.3, 0.1])}\n" 
      f"weighter average (motor temperature): {weighted_average(data_ts_te_m, [0.6, 0.3, 0.1])}\n" 
      f"weighter average (motor torque): {weighted_average(data_ts_nm_m, [0.6, 0.3, 0.1])}")
# Out:
# weighter average (motor speed): 430.99999999999994
# weighter average (motor current): 118.99999999999999
# weighter average (motor temperature): 41.0
# weighter average (motor torque): 287.29999999999995

# %% [markdown]
# ### Exponential smoothing

# %%
def exponential_smoothing(series, alpha):
    """
        series - dataset with timestamps
        alpha - float [0.0, 1.0], smoothing parameter
    """
    result = [series[0]] # first value is same as series
    for n in range(1, len(series)):
        result.append(alpha * series[n] + (1 - alpha) * result[n-1])
    
    model = pd.Series(result, index=series.index)
    
    return model

# %%
exp_smt_sd = exponential_smoothing(data_ts_sd_m['Motor speed'], 0.07)
exp_smt_cu = exponential_smoothing(data_ts_cu_m['Current'], 0.07)
exp_smt_te = exponential_smoothing(data_ts_te_m['Temperature'], 0.07)
exp_smt_nm = exponential_smoothing(data_ts_nm_m['Torque'], 0.07)

# %%
plotModel(data_ts_sd_m['Motor speed'], 
            data_ts_cu_m['Current'], 
            data_ts_te_m['Temperature'], 
            data_ts_nm_m['Torque'], 
            exp_smt_sd, 
            exp_smt_cu, 
            exp_smt_te, 
            exp_smt_nm, 
            'Exp.Smoothing', predictive_mode=False)

# %% [markdown]
# ### Double exponential smoothing

# %%
def double_exponential_smoothing(series, alpha, beta):
    """
        series - dataset with timeseries
        alpha - float [0.0, 1.0], smoothing parameter for level
        beta - float [0.0, 1.0], smoothing parameter for trend
    """
    # first value is same as series
    result = [series[0]]
    for n in range(1, len(series)+1):
        if n == 1:
            level, trend = series[0], series[1] - series[0]
        if n >= len(series): # forecasting
            value = result[-1]
        else:
            value = series[n]
        last_level, level = level, alpha*value + (1-alpha)*(level+trend)
        trend = beta*(level-last_level) + (1-beta)*trend
        result.append(level+trend)
    
    model = pd.Series(result[:1441], index=series.index)
    
    return model

# %%
dbl_exp_smt_sd = double_exponential_smoothing(data_ts_sd_m['Motor speed'], 0.03, 0.9)
dbl_exp_smt_cu = double_exponential_smoothing(data_ts_cu_m['Current'], 0.03, 0.9)
dbl_exp_smt_te = double_exponential_smoothing(data_ts_te_m['Temperature'], 0.3, 0.9)
dbl_exp_smt_nm = double_exponential_smoothing(data_ts_nm_m['Torque'], 0.03, 0.9)

# %%
plotModel(data_ts_sd_m['Motor speed'], 
            data_ts_cu_m['Current'], 
            data_ts_te_m['Temperature'], 
            data_ts_nm_m['Torque'], 
            dbl_exp_smt_sd, 
            dbl_exp_smt_cu, 
            dbl_exp_smt_te, 
            dbl_exp_smt_nm, 
            'Double Exp.Smoothing', predictive_mode=False)

# %% [markdown]
# ### Holt-Winters

# %%
def timeseriesCVscore(params, series, loss_function=mean_squared_error, slen=24):
    """
        Returns error on CV  
        
        params - vector of parameters for optimization
        series - dataset with timeseries
        slen - season length for Holt-Winters model
    """
    errors = []
    
    values = series.values
    alpha, beta, gamma = params
    
    tscv = TimeSeriesSplit(n_splits=3) 

    for train, test in tscv.split(values):

        model = HoltWinters(series=values[train], slen=slen, 
                            alpha=alpha, beta=beta, gamma=gamma, n_preds=len(test))
        model.triple_exponential_smoothing()
        
        predictions = model.result[-len(test):]
        actual = values[test]
        error = loss_function(predictions, actual)
        errors.append(error)
        
    return np.mean(np.array(errors))

# %%
class HoltWinters:
    
    """
    Holt-Winters model with the anomalies detection using Brutlag method
    
    # series - initial time series
    # slen - length of a season
    # alpha, beta, gamma - Holt-Winters model coefficients
    # n_preds - predictions horizon
    # scaling_factor - sets the width of the confidence interval by Brutlag (usually takes values from 2 to 3)
    
    """
    def __init__(self, series, slen, alpha, beta, gamma, n_preds, scaling_factor=1.96):
        self.series = series
        self.slen = slen
        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma
        self.n_preds = n_preds
        self.scaling_factor = scaling_factor
        
        
    def initial_trend(self):
        sum = 0.0
        for i in range(self.slen):
            sum += float(self.series[i+self.slen] - self.series[i]) / self.slen
        return sum / self.slen  
    
    def initial_seasonal_components(self):
        seasonals = {}
        season_averages = []
        n_seasons = int(len(self.series)/self.slen)
        for j in range(n_seasons):
            season_averages.append(sum(self.series[self.slen*j:self.slen*j+self.slen])/float(self.slen))
        for i in range(self.slen):
            sum_of_vals_over_avg = 0.0
            for j in range(n_seasons):
                sum_of_vals_over_avg += self.series[self.slen*j+i]-season_averages[j]
            seasonals[i] = sum_of_vals_over_avg/n_seasons
        return seasonals   
   
    def triple_exponential_smoothing(self):
        self.result = []
        self.Smooth = []
        self.Season = []
        self.Trend = []
        self.PredictedDeviation = []
        self.UpperBond = []
        self.LowerBond = []
        
        seasonals = self.initial_seasonal_components()
        
        for i in range(len(self.series)+self.n_preds):
            if i == 0: 
                smooth = self.series[0]
                trend = self.initial_trend()
                self.result.append(self.series[0])
                self.Smooth.append(smooth)
                self.Trend.append(trend)
                self.Season.append(seasonals[i%self.slen])
                
                self.PredictedDeviation.append(0)
                
                self.UpperBond.append(self.result[0] + 
                                      self.scaling_factor * 
                                      self.PredictedDeviation[0])
                
                self.LowerBond.append(self.result[0] - 
                                      self.scaling_factor * 
                                      self.PredictedDeviation[0])
                continue
                
            if i >= len(self.series): 
                m = i - len(self.series) + 1
                self.result.append((smooth + m*trend) + seasonals[i%self.slen])
                
                self.PredictedDeviation.append(self.PredictedDeviation[-1]*1.01) 
                
            else:
                val = self.series[i]
                last_smooth, smooth = smooth, self.alpha*(val-seasonals[i%self.slen]) + (1-self.alpha)*(smooth+trend)
                trend = self.beta * (smooth-last_smooth) + (1-self.beta)*trend
                seasonals[i%self.slen] = self.gamma*(val-smooth) + (1-self.gamma)*seasonals[i%self.slen]
                self.result.append(smooth+trend+seasonals[i%self.slen])
                
                self.PredictedDeviation.append(self.gamma * np.abs(self.series[i] - self.result[i]) 
                                               + (1-self.gamma)*self.PredictedDeviation[-1])
                     
            self.UpperBond.append(self.result[-1] + 
                                  self.scaling_factor * 
                                  self.PredictedDeviation[-1])

            self.LowerBond.append(self.result[-1] - 
                                  self.scaling_factor * 
                                  self.PredictedDeviation[-1])

            self.Smooth.append(smooth)
            self.Trend.append(trend)
            self.Season.append(seasonals[i%self.slen])

# %%
def selection_of_parameters(data, leave_data_for_testing=400, n_preds=400):
     
    train = data[:-leave_data_for_testing]
    test = data[len(data)-leave_data_for_testing:]
    x = [0, 0, 0]
    
    opt = minimize(timeseriesCVscore, x0=x, 
               args=(train, mean_squared_error), 
               method="TNC", bounds = ((0, 1), (0, 1), (0, 1))
              )
    
    alpha_final, beta_final, gamma_final = opt.x
    
    model = HoltWinters(train, slen = 12, 
                    alpha = alpha_final, 
                    beta = beta_final, 
                    gamma = gamma_final, 
                    n_preds = n_preds, scaling_factor = 3)
    model.triple_exponential_smoothing()
    
    hw_model = pd.Series(model.result[1041:], index=data[len(data)-leave_data_for_testing:].index)
    
    mape, evs, maxerror, mae, mse, msle, r2, mpd = quality_metrics(test.values, hw_model.values)
        
    return hw_model, mse, mape, maxerror

# %%
model_hw_speed, sd_hw_mse, sd_hw_mape, sd_hw_maxerror = selection_of_parameters(data_ts_sd_m['Motor speed'], leave_data_for_testing=400, n_preds=400)
model_hw_current, cu_hw_mse, cu_hw_mape, cu_hw_maxerror, = selection_of_parameters(data_ts_cu_m['Current'], leave_data_for_testing=400, n_preds=400)
model_hw_temperature, te_hw_mse, te_hw_mape, te_hw_maxerror = selection_of_parameters(data_ts_te_m['Temperature'], leave_data_for_testing=400, n_preds=400)
model_hw_torque, nm_hw_mse, nm_hw_mape, nm_hw_maxerror = selection_of_parameters(data_ts_nm_m['Torque'], leave_data_for_testing=400, n_preds=400)

# %%
plotModel(data_ts_sd_m['Motor speed'], 
          data_ts_cu_m['Current'], 
          data_ts_te_m['Temperature'], 
          data_ts_nm_m['Torque'], 
          model_hw_speed, 
          model_hw_current, 
          model_hw_temperature, 
          model_hw_torque, 
          'HoltWinters', 
          sd_hw_mse, sd_hw_mape, sd_hw_maxerror, 
          cu_hw_mse, cu_hw_mape, cu_hw_maxerror,
          te_hw_mse, te_hw_mape, te_hw_maxerror, 
          nm_hw_mse, nm_hw_mape, nm_hw_maxerror,
          predictive_mode=True)

# %% [markdown]
# ## Autoregressive model
# ### AR

# %%
def ar_model(data):
    
    train, test = split(data, size=0.3)
    model = AR(train)
    model_fit = model.fit()
    predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=True)
    mape, evs, maxerror, mae, mse, msle, r2, mpd = quality_metrics(test.values, predictions.values)
    
    return predictions, mape, mse, maxerror

# %%
ar_sd_predictions, sd_ar_mape, sd_ar_mse, sd_ar_maxerror = ar_model(data_ts_sd_m)
ar_cu_predictions, cu_ar_mape, cu_ar_mse, cu_ar_maxerror = ar_model(data_ts_cu_m)
ar_te_predictions, te_ar_mape, te_ar_mse, te_ar_maxerror = ar_model(data_ts_te_m)
ar_nm_predictions, nm_ar_mape, nm_ar_mse, nm_ar_maxerror = ar_model(data_ts_nm_m)

# %%
plotModel(data_ts_sd_m['Motor speed'], 
          data_ts_cu_m['Current'], 
          data_ts_te_m['Temperature'], 
          data_ts_nm_m['Torque'], 
          ar_sd_predictions, 
          ar_cu_predictions, 
          ar_te_predictions, 
          ar_nm_predictions, 
          'AR', 
          sd_ar_mse, sd_ar_mape, sd_ar_maxerror, 
          cu_ar_mse, cu_ar_mape, cu_ar_maxerror,
          te_ar_mse, te_ar_mape, te_ar_maxerror, 
          nm_ar_mse, nm_ar_mape, nm_ar_maxerror,
          predictive_mode=True)

# %% [markdown]
# ### ARIMA

# %%
def arima(data, start_p=2, start_q=2, start_d=1, max_p=2, max_q=2, max_d=1):
    
    train, test = split(data)
    
    model = pm.auto_arima(train, start_p=start_p, start_q=start_q, max_p=max_p, max_q=max_q, start_d=start_d, max_d=max_d)
    forecasts = model.predict(test.shape[0])
    forecasts = pd.Series(forecasts, index=data[len(train):].index)
    mape, evs, maxerror, mae, mse, msle, r2, mpd = quality_metrics(test.values, forecasts.values)
    
    return forecasts, test, mse, mape, maxerror

# %%
sd_arima_predictions, sd_arima_test, sd_arima_mse, sd_arima_mape, sd_arima_maxerror = arima(data_ts_sd_m)
cu_arima_predictions, cu_arima_test, cu_arima_mse, cu_arima_mape, cu_arima_maxerror = arima(data_ts_cu_m)
te_arima_predictions, te_arima_test, te_arima_mse, te_arima_mape, te_arima_maxerror = arima(data_ts_te_m)
nm_arima_predictions, nm_arima_test, nm_arima_mse, nm_arima_mape, nm_arima_maxerror = arima(data_ts_nm_m)

# %%
plotModel(data_ts_sd_m['Motor speed'], 
          data_ts_cu_m['Current'], 
          data_ts_te_m['Temperature'], 
          data_ts_nm_m['Torque'], 
          sd_arima_predictions, 
          cu_arima_predictions, 
          te_arima_predictions, 
          nm_arima_predictions, 
          'ARIMA', 
          sd_arima_mse, sd_arima_mape, sd_arima_maxerror, 
          cu_arima_mse, cu_arima_mape, cu_arima_maxerror,
          te_arima_mse, te_arima_mape, te_arima_maxerror, 
          nm_arima_mse, nm_arima_mape, nm_arima_maxerror,
          predictive_mode=True)

# %% [markdown]
# ### SARIMA

# %%
def SARIMA(data, p=2, q=3, P=0, Q=1, d=1, D=1, s=6):
    
    train, test = split(data)
    
    model = sm.tsa.statespace.SARIMAX(train, order=(p, d, q), 
                                      seasonal_order=(P, D, Q, s)).fit(disp=-1)
    
    forecast = model.forecast(steps=432)
    
    mape, evs, maxerror, mae, mse, msle, r2, mpd = quality_metrics(test.values, forecast.values)
    
    return forecast, mape, mse, maxerror

# %%
sd_sarima_predictions, sd_sar_mape, sd_sar_mse, sd_sar_maxerror = SARIMA(data_ts_sd_m['Motor speed'])
cu_sarima_predictions, cu_sar_mape, cu_sar_mse, cu_sar_maxerror = SARIMA(data_ts_cu_m['Current'])
te_sarima_predictions, te_sar_mape, te_sar_mse, te_sar_maxerror = SARIMA(data_ts_te_m['Temperature'])
nm_sarima_predictions, nm_sar_mape, nm_sar_mse, nm_sar_maxerror = SARIMA(data_ts_nm_m['Torque'])

# %%
plotModel(data_ts_sd_m['Motor speed'], 
          data_ts_cu_m['Current'], 
          data_ts_te_m['Temperature'], 
          data_ts_nm_m['Torque'], 
          sd_sarima_predictions, 
          cu_sarima_predictions, 
          te_sarima_predictions, 
          nm_sarima_predictions, 
          'SARIMA', 
          sd_sar_mse, sd_sar_mape, sd_sar_maxerror, 
          cu_sar_mse, cu_sar_mape, cu_sar_maxerror,
          te_sar_mse, te_sar_mape, te_sar_maxerror, 
          nm_sar_mse, nm_sar_mape, nm_sar_maxerror,
          predictive_mode=True)

# %% [markdown]
# ## Hidden Markov Model

# %%
def HMM(data, n_components=20, n_iter=1000):
    
    train, test = split(data)
    
    model = GaussianHMM(n_components=n_components,
                        covariance_type="diag",
                        n_iter=n_iter)
    
    HMM = model.fit(data)
    labels = model.predict(data)
    means = np.zeros_like(data)
    
    for i in range(model.n_components):
        means[labels == i] = model.means_[i]
    
    dataframe = pd.DataFrame(means)
    new_dataframe = dataframe.iloc[:,0].values
    
    forecast = pd.Series(new_dataframe, index=data.index)
    
    mape, evs, maxerror, mae, mse, msle, r2, mpd = quality_metrics(data.values, forecast.values)

    return forecast, mse, mape, maxerror

# %%
sd_hmm_predictions, sd_hmm_mape, sd_hmm_mse, sd_hmm_maxerror = HMM(data_ts_sd_m)
cu_hmm_predictions, cu_hmm_mape, cu_hmm_mse, cu_hmm_maxerror = HMM(data_ts_cu_m)
te_hmm_predictions, te_hmm_mape, te_hmm_mse, te_hmm_maxerror = HMM(data_ts_te_m)
nm_hmm_predictions, nm_hmm_mape, nm_hmm_mse, nm_hmm_maxerror = HMM(data_ts_nm_m)

# %%
plotModel(data_ts_sd_m['Motor speed'], 
          data_ts_cu_m['Current'], 
          data_ts_te_m['Temperature'], 
          data_ts_nm_m['Torque'], 
          sd_hmm_predictions, 
          cu_hmm_predictions, 
          te_hmm_predictions, 
          nm_hmm_predictions, 
          'HMM', 
          sd_hmm_mse, sd_hmm_mape, sd_hmm_maxerror, 
          cu_hmm_mse, cu_hmm_mape, cu_hmm_maxerror,
          te_hmm_mse, te_hmm_mape, te_hmm_maxerror, 
          nm_hmm_mse, nm_hmm_mape, nm_hmm_maxerror,
          predictive_mode=True)

# %% [markdown]
# ## Linear Regression

# %%
def linear_regression(data, start, end):
    
    data_ = pd.DataFrame(data.copy())
    data_.columns = ["y"]

    for i in range(start, end):
        data_["lag_{}".format(i)] = data_.y.shift(i)    
    
    y = data_.dropna().y
    X = data_.dropna().drop(['y'], axis=1)

    X_train, X_test, y_train, y_test = timeseries_train_test_split(X, y, test_size=0.3)

    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    lr = LinearRegression()
    lr.fit(X_train_scaled, y_train)
    
    prediction = lr.predict(X_test_scaled)
    forecast = pd.Series(prediction, index=y_test.index)
    
    mape, evs, maxerror, mae, mse, msle, r2, mpd = quality_metrics(y_test.values, forecast.values)
    
    return forecast, mse, mape, maxerror

# %%
sd_lr_predictions, sd_lr_mape, sd_lr_mse, sd_lr_maxerror = linear_regression(data_ts_sd_m['Motor speed'], 20, 40)
cu_lr_predictions, cu_lr_mape, cu_lr_mse, cu_lr_maxerror = linear_regression(data_ts_cu_m['Current'], 20, 40)
te_lr_predictions, te_lr_mape, te_lr_mse, te_lr_maxerror = linear_regression(data_ts_te_m['Temperature'], 20, 40)
nm_lr_predictions, nm_lr_mape, nm_lr_mse, nm_lr_maxerror = linear_regression(data_ts_nm_m['Torque'], 20, 40)

# %%
plotModel(data_ts_sd_m['Motor speed'], 
          data_ts_cu_m['Current'], 
          data_ts_te_m['Temperature'], 
          data_ts_nm_m['Torque'], 
          sd_lr_predictions, 
          cu_lr_predictions, 
          te_lr_predictions, 
          nm_lr_predictions,
          'LR', 
          sd_lr_mse, sd_lr_mape, sd_lr_maxerror, 
          cu_lr_mse, cu_lr_mape, cu_lr_maxerror,
          te_lr_mse, te_lr_mape, te_lr_maxerror, 
          nm_lr_mse, nm_lr_mape, nm_lr_maxerror,
          predictive_mode=True)

# %% [markdown]
# ## Gradient boosting on decision trees

# %% [markdown]
# ### XGBoost

# %%
def xgboost_regression(data, start, end, trees):
    
    data_ = pd.DataFrame(data.copy())
    data_.columns = ["y"]

    for i in range(start, end):
        data_["lag_{}".format(i)] = data_.y.shift(i)    
    
    y = data_.dropna().y
    X = data_.dropna().drop(['y'], axis=1)
    
    X_train, X_test, y_train, y_test = timeseries_train_test_split(X, y, test_size=0.3)

    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    dtrain = xgb.DMatrix(X_train_scaled, label=y_train)
    dtest = xgb.DMatrix(X_test_scaled, label=y_test)
    
    params = {
        'objective': 'reg:linear',
        'booster':'gblinear',
        'verbosity' : 0
                            }
    
    cv = xgb.cv(params, dtrain, metrics = ('rmse'), verbose_eval=False, show_stdv=False, num_boost_round=trees)
    
    xgboost = xgb.train(params, dtrain, num_boost_round=cv['test-rmse-mean'].argmin())
    
    prediction = xgboost.predict(dtest)
    forecast = pd.Series(prediction, index=y_test.index)
    
    mape, evs, maxerror, mae, mse, msle, r2, mpd = quality_metrics(y_test.values, forecast.values)

    return forecast, mape, mse, maxerror

# %%
sd_xgb_predictions, sd_xgb_mape, sd_xgb_mse, sd_xgb_maxerror = xgboost_regression(data_ts_sd_m['Motor speed'], 200, 220, 20)
cu_xgb_predictions, cu_xgb_mape, cu_xgb_mse, cu_xgb_maxerror = xgboost_regression(data_ts_cu_m['Current'], 20, 40, 10)
te_xgb_predictions, te_xgb_mape, te_xgb_mse, te_xgb_maxerror = xgboost_regression(data_ts_te_m['Temperature'], 5, 15, 100)
nm_xgb_predictions, nm_xgb_mape, nm_xgb_mse, nm_xgb_maxerror = xgboost_regression(data_ts_nm_m['Torque'], 20, 40, 10)

# %%
plotModel(data_ts_sd_m['Motor speed'], 
          data_ts_cu_m['Current'], 
          data_ts_te_m['Temperature'], 
          data_ts_nm_m['Torque'], 
          sd_xgb_predictions, 
          cu_xgb_predictions, 
          te_xgb_predictions, 
          nm_xgb_predictions, 
          'XGBoost', 
          sd_xgb_mse, sd_xgb_mape, sd_xgb_maxerror, 
          cu_xgb_mse, cu_xgb_mape, cu_xgb_maxerror,
          te_xgb_mse, te_xgb_mape, te_xgb_maxerror, 
          nm_xgb_mse, nm_xgb_mape, nm_xgb_maxerror,
          predictive_mode=True)

# %% [markdown]
# ### CatBoost

# %%
def catboost_regression(data, start, end):
    
    data_ = pd.DataFrame(data.copy())
    data_.columns = ["y"]

    for i in range(start, end):
        data_["lag_{}".format(i)] = data_.y.shift(i)    
    
    y = data_.dropna().y
    X = data_.dropna().drop(['y'], axis=1)
    
    X_train, X_test, y_train, y_test = timeseries_train_test_split(X, y, test_size=0.3)

    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    catboost = CatBoostRegressor(iterations=100, depth=4, learning_rate=0.7,
                          loss_function='RMSE', verbose=0)
    
    catboost.fit(X_train_scaled, y_train, verbose=0)
    
    prediction = catboost.predict(X_test_scaled)
    forecast = pd.Series(prediction, index=y_test.index)
    
    mape, evs, maxerror, mae, mse, msle, r2, mpd = quality_metrics(y_test.values, forecast.values)

    return forecast, mape, mse, maxerror

# %%
sd_cat_predictions, sd_cat_mape, sd_cat_mse, sd_cat_maxerror = catboost_regression(data_ts_sd_m['Motor speed'], 20, 40)
cu_cat_predictions, cu_cat_mape, cu_cat_mse, cu_cat_maxerror = catboost_regression(data_ts_cu_m['Current'], 20, 40)
te_cat_predictions, te_cat_mape, te_cat_mse, te_cat_maxerror = catboost_regression(data_ts_te_m['Temperature'], 20, 40)
nm_cat_predictions, nm_cat_mape, nm_cat_mse, nm_cat_maxerror = catboost_regression(data_ts_nm_m['Torque'], 20, 40)

# %%
plotModel(data_ts_sd_m['Motor speed'], 
          data_ts_cu_m['Current'], 
          data_ts_te_m['Temperature'], 
          data_ts_nm_m['Torque'], 
          sd_cat_predictions, 
          cu_cat_predictions, 
          te_cat_predictions, 
          nm_cat_predictions, 
          'CatBoost', 
          sd_cat_mse, sd_cat_mape, sd_cat_maxerror, 
          cu_cat_mse, cu_cat_mape, cu_cat_maxerror,
          te_cat_mse, te_cat_mape, te_cat_maxerror, 
          nm_cat_mse, nm_cat_mape, nm_cat_maxerror,
          predictive_mode=True)

# %% [markdown]
# ### LightGBM

# %%
def lgbm_regression(data, start, end, trees=10):
    
    data_ = pd.DataFrame(data.copy())
    data_.columns = ["y"]

    for i in range(start, end):
        data_["lag_{}".format(i)] = data_.y.shift(i)    
    
    y = data_.dropna().y
    X = data_.dropna().drop(['y'], axis=1)
    
    X_train, X_test, y_train, y_test = timeseries_train_test_split(X, y, test_size=0.3)

    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    params = {"objective" : "regression", "metric" : "mae", 'n_estimators':20000, 
              "learning_rate" : 0.1, 
               "num_threads" : 4,
              "colsample_bytree" : 0.7
             }
    
    lgbTrain = lgb.Dataset(X_train_scaled, label=y_train)
    
    model = lgb.train(params, lgbTrain, verbose_eval=0)
    
    prediction = model.predict(X_test_scaled)
    forecast = pd.Series(prediction, index=y_test.index)
    
    mape, evs, maxerror, mae, mse, msle, r2, mpd = quality_metrics(y_test.values, forecast.values)

    return forecast, mape, mse, maxerror

# %%
sd_lgbm_predictions, sd_lgbm_mape, sd_lgbm_mse, sd_lgbm_maxerror = lgbm_regression(data_ts_sd_m['Motor speed'], 20, 40)
cu_lgbm_predictions, cu_lgbm_mape, cu_lgbm_mse, cu_lgbm_maxerror = lgbm_regression(data_ts_cu_m['Current'], 20, 40)
te_lgbm_predictions, te_lgbm_mape, te_lgbm_mse, te_lgbm_maxerror = lgbm_regression(data_ts_te_m['Temperature'], 20, 40)
nm_lgbm_predictions, nm_lgbm_mape, nm_lgbm_mse, nm_lgbm_maxerror = lgbm_regression(data_ts_nm_m['Torque'], 20, 40)

# %%
plotModel(data_ts_sd_m['Motor speed'], 
          data_ts_cu_m['Current'], 
          data_ts_te_m['Temperature'], 
          data_ts_nm_m['Torque'], 
          sd_lgbm_predictions, 
          cu_lgbm_predictions, 
          te_lgbm_predictions, 
          nm_lgbm_predictions, 
          'LightGBM', 
          sd_lgbm_mse, sd_lgbm_mape, sd_lgbm_maxerror, 
          cu_lgbm_mse, cu_lgbm_mape, cu_lgbm_maxerror,
          te_lgbm_mse, te_lgbm_mape, te_lgbm_maxerror, 
          nm_lgbm_mse, nm_lgbm_mape, nm_lgbm_maxerror,
          predictive_mode=True)

# %% [markdown]
# ## Facebook Prophet

# %%
def fbp(data, predictions=432):
    
    data_ = data
    data = data.reset_index()
    data.columns = ['ds', 'y']
    train_data = data[:-predictions]
    
    model = Prophet(daily_seasonality = False, yearly_seasonality = False, weekly_seasonality = False,
                seasonality_mode = 'multiplicative')
    
    model.fit(train_data)
    future = model.make_future_dataframe(periods=predictions, freq='T')
    forecast = model.predict(future)
    
    forecast['fact'] = data['y'].reset_index(drop = True)
    
    y_pred = forecast['yhat'].values
    y_true = forecast['fact'].values
    
    final_forecast = pd.Series(y_pred, index=data_.index)
    
    mape, evs, maxerror, mae, mse, msle, r2, mpd = quality_metrics(y_true, final_forecast.values)

    return final_forecast, mape, mse, maxerror

# %%
sd_fbp_predictions, sd_fbp_mape, sd_fbp_mse, sd_fbp_maxerror = fbp(data_ts_sd_m['Motor speed'])
cu_fbp_predictions, cu_fbp_mape, cu_fbp_mse, cu_fbp_maxerror = fbp(data_ts_cu_m['Current'])
te_fbp_predictions, te_fbp_mape, te_fbp_mse, te_fbp_maxerror = fbp(data_ts_te_m['Temperature'])
nm_fbp_predictions, nm_fbp_mape, nm_fbp_mse, nm_fbp_maxerror = fbp(data_ts_nm_m['Torque'])

# %%
plotModel(data_ts_sd_m['Motor speed'], 
          data_ts_cu_m['Current'], 
          data_ts_te_m['Temperature'], 
          data_ts_nm_m['Torque'], 
          sd_fbp_predictions, 
          cu_fbp_predictions, 
          te_fbp_predictions, 
          nm_fbp_predictions, 
          'Facebook Prophet', 
          sd_fbp_mse, sd_fbp_mape, sd_fbp_maxerror, 
          cu_fbp_mse, cu_fbp_mape, cu_fbp_maxerror,
          te_fbp_mse, te_fbp_mape, te_fbp_maxerror, 
          nm_fbp_mse, nm_fbp_mape, nm_fbp_maxerror,
          predictive_mode=True)

# %% [markdown]
# ## Amazon Gluon TS

# %%
def gluon_ts(data, cell_type='gru', epochs=30, batch_size=1, num_batches_per_epoch=1):
    
    train, test = split(data)
    
    data = common.ListDataset([{
        "start": train.index[0],
        "target": train[:len(train)].squeeze()
    }],
                              freq="T")

    estimator = DeepAREstimator(
        freq="T", 
        prediction_length=len(test), 
        cell_type=cell_type,
        trainer=Trainer(epochs=epochs))
    
    predictor = estimator.train(training_data=data)
    prediction = next(predictor.predict(data))
    
    forecast = pd.Series(prediction.mean, index=test.index)

    mape, evs, maxerror, mae, mse, msle, r2, mpd = quality_metrics(test.values, forecast.values)
    
    pred = forecast[:len(forecast)-1]
     
    return pred, mape, mse, maxerror

# %%
sd_gluon_predictions, sd_gluon_mape, sd_gluon_mse, sd_gluon_maxerror = gluon_ts(data_ts_sd_m)
cu_gluon_predictions, cu_gluon_mape, cu_gluon_mse, cu_gluon_maxerror = gluon_ts(data_ts_cu_m)
te_gluon_predictions, te_gluon_mape, te_gluon_mse, te_gluon_maxerror = gluon_ts(data_ts_te_m)
nm_gluon_predictions, nm_gluon_mape, nm_gluon_mse, nm_gluon_maxerror = gluon_ts(data_ts_nm_m)
# Out:
# WARNING:root:You have set `num_workers` to a non zero value, however, currently multiprocessing is not supported on windows and therefore`num_workers will be set to 0.
# INFO:gluonts.trainer:Start model training
# learning rate from ``lr_scheduler`` has been overwritten by ``learning_rate`` in optimizer.
# INFO:gluonts.trainer:Epoch[0] Learning rate is 0.001
#   0%|                                                              | 0/50 [00:00<?, ?it/s]INFO:gluonts.trainer:Number of parameters in DeepARTrainingNetwork: 18724
# 100%|████████████████████| 50/50 [01:09<00:00,  1.39s/it, epoch=1/30, avg_epoch_loss=5.74]
# INFO:gluonts.trainer:Epoch[0] Elapsed time 69.738 seconds
# INFO:gluonts.trainer:Epoch[0] Evaluation metric 'epoch_loss'=5.739013
# INFO:gluonts.trainer:Epoch[1] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:49<00:00,  1.01it/s, epoch=2/30, avg_epoch_loss=4.57]
# INFO:gluonts.trainer:Epoch[1] Elapsed time 49.751 seconds
# INFO:gluonts.trainer:Epoch[1] Evaluation metric 'epoch_loss'=4.566544
# INFO:gluonts.trainer:Epoch[2] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:48<00:00,  1.03it/s, epoch=3/30, avg_epoch_loss=5.27]
# INFO:gluonts.trainer:Epoch[2] Elapsed time 48.533 seconds
# INFO:gluonts.trainer:Epoch[2] Evaluation metric 'epoch_loss'=5.273244
# INFO:gluonts.trainer:Epoch[3] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:47<00:00,  1.04it/s, epoch=4/30, avg_epoch_loss=4.28]
# INFO:gluonts.trainer:Epoch[3] Elapsed time 47.964 seconds
# INFO:gluonts.trainer:Epoch[3] Evaluation metric 'epoch_loss'=4.279897
# INFO:gluonts.trainer:Epoch[4] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:47<00:00,  1.05it/s, epoch=5/30, avg_epoch_loss=5.39]
# INFO:gluonts.trainer:Epoch[4] Elapsed time 47.732 seconds
# INFO:gluonts.trainer:Epoch[4] Evaluation metric 'epoch_loss'=5.390437
# INFO:gluonts.trainer:Epoch[5] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:48<00:00,  1.04it/s, epoch=6/30, avg_epoch_loss=3.86]
# INFO:gluonts.trainer:Epoch[5] Elapsed time 48.038 seconds
# INFO:gluonts.trainer:Epoch[5] Evaluation metric 'epoch_loss'=3.860200
# INFO:gluonts.trainer:Epoch[6] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:47<00:00,  1.05it/s, epoch=7/30, avg_epoch_loss=3.49]
# INFO:gluonts.trainer:Epoch[6] Elapsed time 47.778 seconds
# INFO:gluonts.trainer:Epoch[6] Evaluation metric 'epoch_loss'=3.489131
# INFO:gluonts.trainer:Epoch[7] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:46<00:00,  1.07it/s, epoch=8/30, avg_epoch_loss=3.72]
# INFO:gluonts.trainer:Epoch[7] Elapsed time 46.856 seconds
# INFO:gluonts.trainer:Epoch[7] Evaluation metric 'epoch_loss'=3.716683
# INFO:gluonts.trainer:Epoch[8] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:47<00:00,  1.05it/s, epoch=9/30, avg_epoch_loss=4.17]
# INFO:gluonts.trainer:Epoch[8] Elapsed time 47.738 seconds
# INFO:gluonts.trainer:Epoch[8] Evaluation metric 'epoch_loss'=4.169789
# INFO:gluonts.trainer:Epoch[9] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:47<00:00,  1.05it/s, epoch=10/30, avg_epoch_loss=3.75]
# INFO:gluonts.trainer:Epoch[9] Elapsed time 47.682 seconds
# INFO:gluonts.trainer:Epoch[9] Evaluation metric 'epoch_loss'=3.745787
# INFO:gluonts.trainer:Epoch[10] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:47<00:00,  1.06it/s, epoch=11/30, avg_epoch_loss=3.67]
# INFO:gluonts.trainer:Epoch[10] Elapsed time 47.325 seconds
# INFO:gluonts.trainer:Epoch[10] Evaluation metric 'epoch_loss'=3.672027
# INFO:gluonts.trainer:Epoch[11] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:48<00:00,  1.04it/s, epoch=12/30, avg_epoch_loss=3.64]
# INFO:gluonts.trainer:Epoch[11] Elapsed time 48.017 seconds
# INFO:gluonts.trainer:Epoch[11] Evaluation metric 'epoch_loss'=3.635864
# INFO:gluonts.trainer:Epoch[12] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:47<00:00,  1.04it/s, epoch=13/30, avg_epoch_loss=3.58]
# INFO:gluonts.trainer:Epoch[12] Elapsed time 47.949 seconds
# INFO:gluonts.trainer:Epoch[12] Evaluation metric 'epoch_loss'=3.582189
# INFO:gluonts.trainer:Epoch[13] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:47<00:00,  1.04it/s, epoch=14/30, avg_epoch_loss=3.55]
# INFO:gluonts.trainer:Epoch[13] Elapsed time 47.982 seconds
# INFO:gluonts.trainer:Epoch[13] Evaluation metric 'epoch_loss'=3.546031
# INFO:gluonts.trainer:Epoch[14] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:46<00:00,  1.07it/s, epoch=15/30, avg_epoch_loss=3.53]
# INFO:gluonts.trainer:Epoch[14] Elapsed time 46.906 seconds
# INFO:gluonts.trainer:Epoch[14] Evaluation metric 'epoch_loss'=3.530160
# INFO:gluonts.trainer:Epoch[15] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:47<00:00,  1.05it/s, epoch=16/30, avg_epoch_loss=3.5]
# INFO:gluonts.trainer:Epoch[15] Elapsed time 47.409 seconds
# INFO:gluonts.trainer:Epoch[15] Evaluation metric 'epoch_loss'=3.495461
# INFO:gluonts.trainer:Epoch[16] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:47<00:00,  1.04it/s, epoch=17/30, avg_epoch_loss=3.47]
# INFO:gluonts.trainer:Epoch[16] Elapsed time 47.910 seconds
# INFO:gluonts.trainer:Epoch[16] Evaluation metric 'epoch_loss'=3.468478
# INFO:gluonts.trainer:Epoch[17] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:48<00:00,  1.04it/s, epoch=18/30, avg_epoch_loss=3.44]
# INFO:gluonts.trainer:Epoch[17] Elapsed time 48.092 seconds
# INFO:gluonts.trainer:Epoch[17] Evaluation metric 'epoch_loss'=3.442838
# INFO:gluonts.trainer:Epoch[18] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:47<00:00,  1.06it/s, epoch=19/30, avg_epoch_loss=3.42]
# INFO:gluonts.trainer:Epoch[18] Elapsed time 47.088 seconds
# INFO:gluonts.trainer:Epoch[18] Evaluation metric 'epoch_loss'=3.415171
# INFO:gluonts.trainer:Epoch[19] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:48<00:00,  1.04it/s, epoch=20/30, avg_epoch_loss=3.4]
# INFO:gluonts.trainer:Epoch[19] Elapsed time 48.237 seconds
# INFO:gluonts.trainer:Epoch[19] Evaluation metric 'epoch_loss'=3.399659
# INFO:gluonts.trainer:Epoch[20] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:47<00:00,  1.05it/s, epoch=21/30, avg_epoch_loss=3.37]
# INFO:gluonts.trainer:Epoch[20] Elapsed time 47.636 seconds
# INFO:gluonts.trainer:Epoch[20] Evaluation metric 'epoch_loss'=3.370094
# INFO:gluonts.trainer:Epoch[21] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:47<00:00,  1.06it/s, epoch=22/30, avg_epoch_loss=3.36]
# INFO:gluonts.trainer:Epoch[21] Elapsed time 47.339 seconds
# INFO:gluonts.trainer:Epoch[21] Evaluation metric 'epoch_loss'=3.359692
# INFO:gluonts.trainer:Epoch[22] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:47<00:00,  1.05it/s, epoch=23/30, avg_epoch_loss=3.34]
# INFO:gluonts.trainer:Epoch[22] Elapsed time 47.418 seconds
# INFO:gluonts.trainer:Epoch[22] Evaluation metric 'epoch_loss'=3.338367
# INFO:gluonts.trainer:Epoch[23] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:48<00:00,  1.04it/s, epoch=24/30, avg_epoch_loss=3.32]
# INFO:gluonts.trainer:Epoch[23] Elapsed time 48.209 seconds
# INFO:gluonts.trainer:Epoch[23] Evaluation metric 'epoch_loss'=3.317808
# INFO:gluonts.trainer:Epoch[24] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:47<00:00,  1.05it/s, epoch=25/30, avg_epoch_loss=3.3]
# INFO:gluonts.trainer:Epoch[24] Elapsed time 47.617 seconds
# INFO:gluonts.trainer:Epoch[24] Evaluation metric 'epoch_loss'=3.295680
# INFO:gluonts.trainer:Epoch[25] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:47<00:00,  1.04it/s, epoch=26/30, avg_epoch_loss=3.29]
# INFO:gluonts.trainer:Epoch[25] Elapsed time 47.883 seconds
# INFO:gluonts.trainer:Epoch[25] Evaluation metric 'epoch_loss'=3.294849
# INFO:gluonts.trainer:Epoch[26] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:47<00:00,  1.04it/s, epoch=27/30, avg_epoch_loss=3.27]
# INFO:gluonts.trainer:Epoch[26] Elapsed time 47.963 seconds
# INFO:gluonts.trainer:Epoch[26] Evaluation metric 'epoch_loss'=3.266875
# INFO:gluonts.trainer:Epoch[27] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:52<00:00,  1.05s/it, epoch=28/30, avg_epoch_loss=3.25]
# INFO:gluonts.trainer:Epoch[27] Elapsed time 52.695 seconds
# INFO:gluonts.trainer:Epoch[27] Evaluation metric 'epoch_loss'=3.247614
# INFO:gluonts.trainer:Epoch[28] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:54<00:00,  1.09s/it, epoch=29/30, avg_epoch_loss=3.25]
# INFO:gluonts.trainer:Epoch[28] Elapsed time 54.501 seconds
# INFO:gluonts.trainer:Epoch[28] Evaluation metric 'epoch_loss'=3.249856
# INFO:gluonts.trainer:Epoch[29] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:54<00:00,  1.08s/it, epoch=30/30, avg_epoch_loss=3.23]
# INFO:gluonts.trainer:Epoch[29] Elapsed time 54.093 seconds
# INFO:gluonts.trainer:Epoch[29] Evaluation metric 'epoch_loss'=3.228034
# INFO:gluonts.trainer:Loading parameters from best epoch (29)
# INFO:gluonts.trainer:Final loss: 3.2280338859558104 (occurred at epoch 29)
# INFO:gluonts.trainer:End model training
# WARNING:root:You have set `num_workers` to a non zero value, however, currently multiprocessing is not supported on windows and therefore`num_workers will be set to 0.
# WARNING:root:You have set `num_workers` to a non zero value, however, currently multiprocessing is not supported on windows and therefore`num_workers will be set to 0.
# INFO:gluonts.trainer:Start model training
# learning rate from ``lr_scheduler`` has been overwritten by ``learning_rate`` in optimizer.
# INFO:gluonts.trainer:Epoch[0] Learning rate is 0.001
#   0%|                                                              | 0/50 [00:00<?, ?it/s]INFO:gluonts.trainer:Number of parameters in DeepARTrainingNetwork: 18724
# 100%|████████████████████| 50/50 [01:16<00:00,  1.53s/it, epoch=1/30, avg_epoch_loss=3.63]
# INFO:gluonts.trainer:Epoch[0] Elapsed time 76.599 seconds
# INFO:gluonts.trainer:Epoch[0] Evaluation metric 'epoch_loss'=3.631648
# INFO:gluonts.trainer:Epoch[1] Learning rate is 0.001
# 100%|█████████████████████| 50/50 [00:50<00:00,  1.00s/it, epoch=2/30, avg_epoch_loss=2.7]
# INFO:gluonts.trainer:Epoch[1] Elapsed time 50.187 seconds
# INFO:gluonts.trainer:Epoch[1] Evaluation metric 'epoch_loss'=2.699840
# INFO:gluonts.trainer:Epoch[2] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:48<00:00,  1.04it/s, epoch=3/30, avg_epoch_loss=2.13]
# INFO:gluonts.trainer:Epoch[2] Elapsed time 48.258 seconds
# INFO:gluonts.trainer:Epoch[2] Evaluation metric 'epoch_loss'=2.126967
# INFO:gluonts.trainer:Epoch[3] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:48<00:00,  1.02it/s, epoch=4/30, avg_epoch_loss=1.99]
# INFO:gluonts.trainer:Epoch[3] Elapsed time 48.974 seconds
# INFO:gluonts.trainer:Epoch[3] Evaluation metric 'epoch_loss'=1.990416
# INFO:gluonts.trainer:Epoch[4] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:48<00:00,  1.02it/s, epoch=5/30, avg_epoch_loss=1.93]
# INFO:gluonts.trainer:Epoch[4] Elapsed time 48.855 seconds
# INFO:gluonts.trainer:Epoch[4] Evaluation metric 'epoch_loss'=1.925428
# INFO:gluonts.trainer:Epoch[5] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:49<00:00,  1.01it/s, epoch=6/30, avg_epoch_loss=1.87]
# INFO:gluonts.trainer:Epoch[5] Elapsed time 49.395 seconds
# INFO:gluonts.trainer:Epoch[5] Evaluation metric 'epoch_loss'=1.874252
# INFO:gluonts.trainer:Epoch[6] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:47<00:00,  1.04it/s, epoch=7/30, avg_epoch_loss=1.85]
# INFO:gluonts.trainer:Epoch[6] Elapsed time 47.972 seconds
# INFO:gluonts.trainer:Epoch[6] Evaluation metric 'epoch_loss'=1.845302
# INFO:gluonts.trainer:Epoch[7] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:49<00:00,  1.00it/s, epoch=8/30, avg_epoch_loss=1.82]
# INFO:gluonts.trainer:Epoch[7] Elapsed time 49.818 seconds
# INFO:gluonts.trainer:Epoch[7] Evaluation metric 'epoch_loss'=1.815037
# INFO:gluonts.trainer:Epoch[8] Learning rate is 0.001
# 100%|█████████████████████| 50/50 [00:49<00:00,  1.00it/s, epoch=9/30, avg_epoch_loss=1.8]
# INFO:gluonts.trainer:Epoch[8] Elapsed time 49.925 seconds
# INFO:gluonts.trainer:Epoch[8] Evaluation metric 'epoch_loss'=1.795094
# INFO:gluonts.trainer:Epoch[9] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:48<00:00,  1.03it/s, epoch=10/30, avg_epoch_loss=1.78]
# INFO:gluonts.trainer:Epoch[9] Elapsed time 48.559 seconds
# INFO:gluonts.trainer:Epoch[9] Evaluation metric 'epoch_loss'=1.782297
# INFO:gluonts.trainer:Epoch[10] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:48<00:00,  1.04it/s, epoch=11/30, avg_epoch_loss=1.75]
# INFO:gluonts.trainer:Epoch[10] Elapsed time 48.150 seconds
# INFO:gluonts.trainer:Epoch[10] Evaluation metric 'epoch_loss'=1.752859
# INFO:gluonts.trainer:Epoch[11] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:49<00:00,  1.01it/s, epoch=12/30, avg_epoch_loss=1.75]
# INFO:gluonts.trainer:Epoch[11] Elapsed time 49.366 seconds
# INFO:gluonts.trainer:Epoch[11] Evaluation metric 'epoch_loss'=1.746991
# INFO:gluonts.trainer:Epoch[12] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:49<00:00,  1.00it/s, epoch=13/30, avg_epoch_loss=1.74]
# INFO:gluonts.trainer:Epoch[12] Elapsed time 49.887 seconds
# INFO:gluonts.trainer:Epoch[12] Evaluation metric 'epoch_loss'=1.737813
# INFO:gluonts.trainer:Epoch[13] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:49<00:00,  1.00it/s, epoch=14/30, avg_epoch_loss=1.73]
# INFO:gluonts.trainer:Epoch[13] Elapsed time 49.900 seconds
# INFO:gluonts.trainer:Epoch[13] Evaluation metric 'epoch_loss'=1.728825
# INFO:gluonts.trainer:Epoch[14] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:48<00:00,  1.04it/s, epoch=15/30, avg_epoch_loss=1.73]
# INFO:gluonts.trainer:Epoch[14] Elapsed time 48.095 seconds
# INFO:gluonts.trainer:Epoch[14] Evaluation metric 'epoch_loss'=1.725128
# INFO:gluonts.trainer:Epoch[15] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:49<00:00,  1.02it/s, epoch=16/30, avg_epoch_loss=1.71]
# INFO:gluonts.trainer:Epoch[15] Elapsed time 49.199 seconds
# INFO:gluonts.trainer:Epoch[15] Evaluation metric 'epoch_loss'=1.711002
# INFO:gluonts.trainer:Epoch[16] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:48<00:00,  1.03it/s, epoch=17/30, avg_epoch_loss=1.7]
# INFO:gluonts.trainer:Epoch[16] Elapsed time 48.520 seconds
# INFO:gluonts.trainer:Epoch[16] Evaluation metric 'epoch_loss'=1.701071
# INFO:gluonts.trainer:Epoch[17] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:49<00:00,  1.02it/s, epoch=18/30, avg_epoch_loss=1.69]
# INFO:gluonts.trainer:Epoch[17] Elapsed time 49.129 seconds
# INFO:gluonts.trainer:Epoch[17] Evaluation metric 'epoch_loss'=1.686304
# INFO:gluonts.trainer:Epoch[18] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:48<00:00,  1.02it/s, epoch=19/30, avg_epoch_loss=1.69]
# INFO:gluonts.trainer:Epoch[18] Elapsed time 48.903 seconds
# INFO:gluonts.trainer:Epoch[18] Evaluation metric 'epoch_loss'=1.690584
# INFO:gluonts.trainer:Epoch[19] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:49<00:00,  1.00it/s, epoch=20/30, avg_epoch_loss=1.7]
# INFO:gluonts.trainer:Epoch[19] Elapsed time 49.767 seconds
# INFO:gluonts.trainer:Epoch[19] Evaluation metric 'epoch_loss'=1.700266
# INFO:gluonts.trainer:Epoch[20] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:50<00:00,  1.00s/it, epoch=21/30, avg_epoch_loss=1.7]
# INFO:gluonts.trainer:Epoch[20] Elapsed time 50.220 seconds
# INFO:gluonts.trainer:Epoch[20] Evaluation metric 'epoch_loss'=1.698860
# INFO:gluonts.trainer:Epoch[21] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:50<00:00,  1.01s/it, epoch=22/30, avg_epoch_loss=1.67]
# INFO:gluonts.trainer:Epoch[21] Elapsed time 50.501 seconds
# INFO:gluonts.trainer:Epoch[21] Evaluation metric 'epoch_loss'=1.674040
# INFO:gluonts.trainer:Epoch[22] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:49<00:00,  1.01it/s, epoch=23/30, avg_epoch_loss=1.67]
# INFO:gluonts.trainer:Epoch[22] Elapsed time 49.745 seconds
# INFO:gluonts.trainer:Epoch[22] Evaluation metric 'epoch_loss'=1.669846
# INFO:gluonts.trainer:Epoch[23] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:50<00:00,  1.00s/it, epoch=24/30, avg_epoch_loss=1.67]
# INFO:gluonts.trainer:Epoch[23] Elapsed time 50.221 seconds
# INFO:gluonts.trainer:Epoch[23] Evaluation metric 'epoch_loss'=1.672613
# INFO:gluonts.trainer:Epoch[24] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:50<00:00,  1.01s/it, epoch=25/30, avg_epoch_loss=1.64]
# INFO:gluonts.trainer:Epoch[24] Elapsed time 50.722 seconds
# INFO:gluonts.trainer:Epoch[24] Evaluation metric 'epoch_loss'=1.644628
# INFO:gluonts.trainer:Epoch[25] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:50<00:00,  1.01s/it, epoch=26/30, avg_epoch_loss=1.65]
# INFO:gluonts.trainer:Epoch[25] Elapsed time 50.597 seconds
# INFO:gluonts.trainer:Epoch[25] Evaluation metric 'epoch_loss'=1.654901
# INFO:gluonts.trainer:Epoch[26] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:49<00:00,  1.01it/s, epoch=27/30, avg_epoch_loss=1.65]
# INFO:gluonts.trainer:Epoch[26] Elapsed time 49.478 seconds
# INFO:gluonts.trainer:Epoch[26] Evaluation metric 'epoch_loss'=1.647059
# INFO:gluonts.trainer:Epoch[27] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:49<00:00,  1.01it/s, epoch=28/30, avg_epoch_loss=1.64]
# INFO:gluonts.trainer:Epoch[27] Elapsed time 49.741 seconds
# INFO:gluonts.trainer:Epoch[27] Evaluation metric 'epoch_loss'=1.643018
# INFO:gluonts.trainer:Epoch[28] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:50<00:00,  1.01s/it, epoch=29/30, avg_epoch_loss=1.63]
# INFO:gluonts.trainer:Epoch[28] Elapsed time 50.274 seconds
# INFO:gluonts.trainer:Epoch[28] Evaluation metric 'epoch_loss'=1.634904
# INFO:gluonts.trainer:Epoch[29] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:50<00:00,  1.00s/it, epoch=30/30, avg_epoch_loss=1.63]
# INFO:gluonts.trainer:Epoch[29] Elapsed time 50.179 seconds
# INFO:gluonts.trainer:Epoch[29] Evaluation metric 'epoch_loss'=1.634175
# INFO:gluonts.trainer:Loading parameters from best epoch (29)
# INFO:gluonts.trainer:Final loss: 1.6341752552986144 (occurred at epoch 29)
# INFO:gluonts.trainer:End model training
# WARNING:root:You have set `num_workers` to a non zero value, however, currently multiprocessing is not supported on windows and therefore`num_workers will be set to 0.
# WARNING:root:You have set `num_workers` to a non zero value, however, currently multiprocessing is not supported on windows and therefore`num_workers will be set to 0.
# INFO:gluonts.trainer:Start model training
# learning rate from ``lr_scheduler`` has been overwritten by ``learning_rate`` in optimizer.
# INFO:gluonts.trainer:Epoch[0] Learning rate is 0.001
#   0%|                                                              | 0/50 [00:00<?, ?it/s]INFO:gluonts.trainer:Number of parameters in DeepARTrainingNetwork: 18724
# 100%|████████████████████| 50/50 [01:16<00:00,  1.53s/it, epoch=1/30, avg_epoch_loss=2.75]
# INFO:gluonts.trainer:Epoch[0] Elapsed time 76.608 seconds
# INFO:gluonts.trainer:Epoch[0] Evaluation metric 'epoch_loss'=2.745672
# INFO:gluonts.trainer:Epoch[1] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:51<00:00,  1.02s/it, epoch=2/30, avg_epoch_loss=1.78]
# INFO:gluonts.trainer:Epoch[1] Elapsed time 51.016 seconds
# INFO:gluonts.trainer:Epoch[1] Evaluation metric 'epoch_loss'=1.778104
# INFO:gluonts.trainer:Epoch[2] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:49<00:00,  1.02it/s, epoch=3/30, avg_epoch_loss=1.47]
# INFO:gluonts.trainer:Epoch[2] Elapsed time 49.144 seconds
# INFO:gluonts.trainer:Epoch[2] Evaluation metric 'epoch_loss'=1.465761
# INFO:gluonts.trainer:Epoch[3] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:48<00:00,  1.04it/s, epoch=4/30, avg_epoch_loss=1.32]
# INFO:gluonts.trainer:Epoch[3] Elapsed time 48.169 seconds
# INFO:gluonts.trainer:Epoch[3] Evaluation metric 'epoch_loss'=1.319888
# INFO:gluonts.trainer:Epoch[4] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:48<00:00,  1.02it/s, epoch=5/30, avg_epoch_loss=1.32]
# INFO:gluonts.trainer:Epoch[4] Elapsed time 48.814 seconds
# INFO:gluonts.trainer:Epoch[4] Evaluation metric 'epoch_loss'=1.317252
# INFO:gluonts.trainer:Epoch[5] Learning rate is 0.001
# 100%|█████████████████████| 50/50 [00:48<00:00,  1.03it/s, epoch=6/30, avg_epoch_loss=1.2]
# INFO:gluonts.trainer:Epoch[5] Elapsed time 48.603 seconds
# INFO:gluonts.trainer:Epoch[5] Evaluation metric 'epoch_loss'=1.200290
# INFO:gluonts.trainer:Epoch[6] Learning rate is 0.001
# 100%|█████████████████████| 50/50 [00:49<00:00,  1.00it/s, epoch=7/30, avg_epoch_loss=1.2]
# INFO:gluonts.trainer:Epoch[6] Elapsed time 49.792 seconds
# INFO:gluonts.trainer:Epoch[6] Evaluation metric 'epoch_loss'=1.202781
# INFO:gluonts.trainer:Epoch[7] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:49<00:00,  1.01it/s, epoch=8/30, avg_epoch_loss=1.11]
# INFO:gluonts.trainer:Epoch[7] Elapsed time 49.554 seconds
# INFO:gluonts.trainer:Epoch[7] Evaluation metric 'epoch_loss'=1.107223
# INFO:gluonts.trainer:Epoch[8] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:48<00:00,  1.02it/s, epoch=9/30, avg_epoch_loss=1.03]
# INFO:gluonts.trainer:Epoch[8] Elapsed time 48.844 seconds
# INFO:gluonts.trainer:Epoch[8] Evaluation metric 'epoch_loss'=1.029468
# INFO:gluonts.trainer:Epoch[9] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:49<00:00,  1.01it/s, epoch=10/30, avg_epoch_loss=1.01]
# INFO:gluonts.trainer:Epoch[9] Elapsed time 49.590 seconds
# INFO:gluonts.trainer:Epoch[9] Evaluation metric 'epoch_loss'=1.010786
# INFO:gluonts.trainer:Epoch[10] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:48<00:00,  1.04it/s, epoch=11/30, avg_epoch_loss=0.971]
# INFO:gluonts.trainer:Epoch[10] Elapsed time 48.021 seconds
# INFO:gluonts.trainer:Epoch[10] Evaluation metric 'epoch_loss'=0.970719
# INFO:gluonts.trainer:Epoch[11] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:48<00:00,  1.04it/s, epoch=12/30, avg_epoch_loss=0.959]
# INFO:gluonts.trainer:Epoch[11] Elapsed time 48.294 seconds
# INFO:gluonts.trainer:Epoch[11] Evaluation metric 'epoch_loss'=0.958816
# INFO:gluonts.trainer:Epoch[12] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:48<00:00,  1.04it/s, epoch=13/30, avg_epoch_loss=0.936]
# INFO:gluonts.trainer:Epoch[12] Elapsed time 48.299 seconds
# INFO:gluonts.trainer:Epoch[12] Evaluation metric 'epoch_loss'=0.936256
# INFO:gluonts.trainer:Epoch[13] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:49<00:00,  1.02it/s, epoch=14/30, avg_epoch_loss=0.893]
# INFO:gluonts.trainer:Epoch[13] Elapsed time 49.035 seconds
# INFO:gluonts.trainer:Epoch[13] Evaluation metric 'epoch_loss'=0.893007
# INFO:gluonts.trainer:Epoch[14] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:48<00:00,  1.03it/s, epoch=15/30, avg_epoch_loss=0.893]
# INFO:gluonts.trainer:Epoch[14] Elapsed time 48.721 seconds
# INFO:gluonts.trainer:Epoch[14] Evaluation metric 'epoch_loss'=0.893015
# INFO:gluonts.trainer:Epoch[15] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:49<00:00,  1.02it/s, epoch=16/30, avg_epoch_loss=0.865]
# INFO:gluonts.trainer:Epoch[15] Elapsed time 49.085 seconds
# INFO:gluonts.trainer:Epoch[15] Evaluation metric 'epoch_loss'=0.864625
# INFO:gluonts.trainer:Epoch[16] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:49<00:00,  1.01it/s, epoch=17/30, avg_epoch_loss=0.953]
# INFO:gluonts.trainer:Epoch[16] Elapsed time 49.588 seconds
# INFO:gluonts.trainer:Epoch[16] Evaluation metric 'epoch_loss'=0.953295
# INFO:gluonts.trainer:Epoch[17] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:50<00:00,  1.00s/it, epoch=18/30, avg_epoch_loss=0.878]
# INFO:gluonts.trainer:Epoch[17] Elapsed time 50.112 seconds
# INFO:gluonts.trainer:Epoch[17] Evaluation metric 'epoch_loss'=0.878127
# INFO:gluonts.trainer:Epoch[18] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:48<00:00,  1.03it/s, epoch=19/30, avg_epoch_loss=0.879]
# INFO:gluonts.trainer:Epoch[18] Elapsed time 48.594 seconds
# INFO:gluonts.trainer:Epoch[18] Evaluation metric 'epoch_loss'=0.878837
# INFO:gluonts.trainer:Epoch[19] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:48<00:00,  1.02it/s, epoch=20/30, avg_epoch_loss=0.858]
# INFO:gluonts.trainer:Epoch[19] Elapsed time 48.902 seconds
# INFO:gluonts.trainer:Epoch[19] Evaluation metric 'epoch_loss'=0.857616
# INFO:gluonts.trainer:Epoch[20] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:49<00:00,  1.01it/s, epoch=21/30, avg_epoch_loss=0.839]
# INFO:gluonts.trainer:Epoch[20] Elapsed time 49.347 seconds
# INFO:gluonts.trainer:Epoch[20] Evaluation metric 'epoch_loss'=0.838835
# INFO:gluonts.trainer:Epoch[21] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:49<00:00,  1.00it/s, epoch=22/30, avg_epoch_loss=0.82]
# INFO:gluonts.trainer:Epoch[21] Elapsed time 49.772 seconds
# INFO:gluonts.trainer:Epoch[21] Evaluation metric 'epoch_loss'=0.820044
# INFO:gluonts.trainer:Epoch[22] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:48<00:00,  1.02it/s, epoch=23/30, avg_epoch_loss=0.815]
# INFO:gluonts.trainer:Epoch[22] Elapsed time 48.976 seconds
# INFO:gluonts.trainer:Epoch[22] Evaluation metric 'epoch_loss'=0.814503
# INFO:gluonts.trainer:Epoch[23] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:49<00:00,  1.02it/s, epoch=24/30, avg_epoch_loss=0.795]
# INFO:gluonts.trainer:Epoch[23] Elapsed time 49.130 seconds
# INFO:gluonts.trainer:Epoch[23] Evaluation metric 'epoch_loss'=0.794766
# INFO:gluonts.trainer:Epoch[24] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:48<00:00,  1.02it/s, epoch=25/30, avg_epoch_loss=0.768]
# INFO:gluonts.trainer:Epoch[24] Elapsed time 48.972 seconds
# INFO:gluonts.trainer:Epoch[24] Evaluation metric 'epoch_loss'=0.767711
# INFO:gluonts.trainer:Epoch[25] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:49<00:00,  1.02it/s, epoch=26/30, avg_epoch_loss=0.769]
# INFO:gluonts.trainer:Epoch[25] Elapsed time 49.151 seconds
# INFO:gluonts.trainer:Epoch[25] Evaluation metric 'epoch_loss'=0.768550
# INFO:gluonts.trainer:Epoch[26] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:49<00:00,  1.02it/s, epoch=27/30, avg_epoch_loss=0.751]
# INFO:gluonts.trainer:Epoch[26] Elapsed time 49.065 seconds
# INFO:gluonts.trainer:Epoch[26] Evaluation metric 'epoch_loss'=0.751321
# INFO:gluonts.trainer:Epoch[27] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:50<00:00,  1.01s/it, epoch=28/30, avg_epoch_loss=0.754]
# INFO:gluonts.trainer:Epoch[27] Elapsed time 50.425 seconds
# INFO:gluonts.trainer:Epoch[27] Evaluation metric 'epoch_loss'=0.753833
# INFO:gluonts.trainer:Epoch[28] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:49<00:00,  1.02it/s, epoch=29/30, avg_epoch_loss=0.734]
# INFO:gluonts.trainer:Epoch[28] Elapsed time 49.180 seconds
# INFO:gluonts.trainer:Epoch[28] Evaluation metric 'epoch_loss'=0.734310
# INFO:gluonts.trainer:Epoch[29] Learning rate is 0.001
# 100%|██████████████████| 50/50 [00:48<00:00,  1.04it/s, epoch=30/30, avg_epoch_loss=0.718]
# INFO:gluonts.trainer:Epoch[29] Elapsed time 48.181 seconds
# INFO:gluonts.trainer:Epoch[29] Evaluation metric 'epoch_loss'=0.718086
# INFO:gluonts.trainer:Loading parameters from best epoch (29)
# INFO:gluonts.trainer:Final loss: 0.718085703253746 (occurred at epoch 29)
# INFO:gluonts.trainer:End model training
# WARNING:root:You have set `num_workers` to a non zero value, however, currently multiprocessing is not supported on windows and therefore`num_workers will be set to 0.
# WARNING:root:You have set `num_workers` to a non zero value, however, currently multiprocessing is not supported on windows and therefore`num_workers will be set to 0.
# INFO:gluonts.trainer:Start model training
# learning rate from ``lr_scheduler`` has been overwritten by ``learning_rate`` in optimizer.
# INFO:gluonts.trainer:Epoch[0] Learning rate is 0.001
#   0%|                                                              | 0/50 [00:00<?, ?it/s]INFO:gluonts.trainer:Number of parameters in DeepARTrainingNetwork: 18724
# 100%|████████████████████| 50/50 [01:13<00:00,  1.47s/it, epoch=1/30, avg_epoch_loss=4.78]
# INFO:gluonts.trainer:Epoch[0] Elapsed time 73.440 seconds
# INFO:gluonts.trainer:Epoch[0] Evaluation metric 'epoch_loss'=4.775359
# INFO:gluonts.trainer:Epoch[1] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:49<00:00,  1.01it/s, epoch=2/30, avg_epoch_loss=4.08]
# INFO:gluonts.trainer:Epoch[1] Elapsed time 49.747 seconds
# INFO:gluonts.trainer:Epoch[1] Evaluation metric 'epoch_loss'=4.081386
# INFO:gluonts.trainer:Epoch[2] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:49<00:00,  1.01it/s, epoch=3/30, avg_epoch_loss=4.19]
# INFO:gluonts.trainer:Epoch[2] Elapsed time 49.486 seconds
# INFO:gluonts.trainer:Epoch[2] Evaluation metric 'epoch_loss'=4.189111
# INFO:gluonts.trainer:Epoch[3] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:48<00:00,  1.03it/s, epoch=4/30, avg_epoch_loss=4.46]
# INFO:gluonts.trainer:Epoch[3] Elapsed time 48.774 seconds
# INFO:gluonts.trainer:Epoch[3] Evaluation metric 'epoch_loss'=4.459289
# INFO:gluonts.trainer:Epoch[4] Learning rate is 0.001
# 100%|███████████████████████| 50/50 [00:49<00:00,  1.01it/s, epoch=5/30, avg_epoch_loss=4]
# INFO:gluonts.trainer:Epoch[4] Elapsed time 49.711 seconds
# INFO:gluonts.trainer:Epoch[4] Evaluation metric 'epoch_loss'=4.000145
# INFO:gluonts.trainer:Epoch[5] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:53<00:00,  1.07s/it, epoch=6/30, avg_epoch_loss=3.58]
# INFO:gluonts.trainer:Epoch[5] Elapsed time 53.660 seconds
# INFO:gluonts.trainer:Epoch[5] Evaluation metric 'epoch_loss'=3.579298
# INFO:gluonts.trainer:Epoch[6] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:53<00:00,  1.08s/it, epoch=7/30, avg_epoch_loss=3.56]
# INFO:gluonts.trainer:Epoch[6] Elapsed time 53.974 seconds
# INFO:gluonts.trainer:Epoch[6] Evaluation metric 'epoch_loss'=3.559422
# INFO:gluonts.trainer:Epoch[7] Learning rate is 0.001
# 100%|█████████████████████| 50/50 [01:07<00:00,  1.36s/it, epoch=8/30, avg_epoch_loss=3.5]
# INFO:gluonts.trainer:Epoch[7] Elapsed time 67.957 seconds
# INFO:gluonts.trainer:Epoch[7] Evaluation metric 'epoch_loss'=3.501642
# INFO:gluonts.trainer:Epoch[8] Learning rate is 0.001
# 100%|████████████████████| 50/50 [01:07<00:00,  1.36s/it, epoch=9/30, avg_epoch_loss=3.43]
# INFO:gluonts.trainer:Epoch[8] Elapsed time 67.975 seconds
# INFO:gluonts.trainer:Epoch[8] Evaluation metric 'epoch_loss'=3.433651
# INFO:gluonts.trainer:Epoch[9] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:56<00:00,  1.13s/it, epoch=10/30, avg_epoch_loss=3.36]
# INFO:gluonts.trainer:Epoch[9] Elapsed time 56.636 seconds
# INFO:gluonts.trainer:Epoch[9] Evaluation metric 'epoch_loss'=3.361029
# INFO:gluonts.trainer:Epoch[10] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:54<00:00,  1.09s/it, epoch=11/30, avg_epoch_loss=3.31]
# INFO:gluonts.trainer:Epoch[10] Elapsed time 54.519 seconds
# INFO:gluonts.trainer:Epoch[10] Evaluation metric 'epoch_loss'=3.313098
# INFO:gluonts.trainer:Epoch[11] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:55<00:00,  1.11s/it, epoch=12/30, avg_epoch_loss=3.27]
# INFO:gluonts.trainer:Epoch[11] Elapsed time 55.680 seconds
# INFO:gluonts.trainer:Epoch[11] Evaluation metric 'epoch_loss'=3.268717
# INFO:gluonts.trainer:Epoch[12] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:57<00:00,  1.15s/it, epoch=13/30, avg_epoch_loss=3.25]
# INFO:gluonts.trainer:Epoch[12] Elapsed time 57.738 seconds
# INFO:gluonts.trainer:Epoch[12] Evaluation metric 'epoch_loss'=3.248366
# INFO:gluonts.trainer:Epoch[13] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:55<00:00,  1.10s/it, epoch=14/30, avg_epoch_loss=3.08]
# INFO:gluonts.trainer:Epoch[13] Elapsed time 55.653 seconds
# INFO:gluonts.trainer:Epoch[13] Evaluation metric 'epoch_loss'=3.078768
# INFO:gluonts.trainer:Epoch[14] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:51<00:00,  1.04s/it, epoch=15/30, avg_epoch_loss=2.83]
# INFO:gluonts.trainer:Epoch[14] Elapsed time 51.991 seconds
# INFO:gluonts.trainer:Epoch[14] Evaluation metric 'epoch_loss'=2.826790
# INFO:gluonts.trainer:Epoch[15] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:51<00:00,  1.03s/it, epoch=16/30, avg_epoch_loss=2.76]
# INFO:gluonts.trainer:Epoch[15] Elapsed time 51.276 seconds
# INFO:gluonts.trainer:Epoch[15] Evaluation metric 'epoch_loss'=2.755127
# INFO:gluonts.trainer:Epoch[16] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:54<00:00,  1.08s/it, epoch=17/30, avg_epoch_loss=2.74]
# INFO:gluonts.trainer:Epoch[16] Elapsed time 54.074 seconds
# INFO:gluonts.trainer:Epoch[16] Evaluation metric 'epoch_loss'=2.737283
# INFO:gluonts.trainer:Epoch[17] Learning rate is 0.001
# 100%|████████████████████| 50/50 [00:54<00:00,  1.09s/it, epoch=18/30, avg_epoch_loss=2.7]
# INFO:gluonts.trainer:Epoch[17] Elapsed time 54.555 seconds
# INFO:gluonts.trainer:Epoch[17] Evaluation metric 'epoch_loss'=2.703323
# INFO:gluonts.trainer:Epoch[18] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:54<00:00,  1.08s/it, epoch=19/30, avg_epoch_loss=2.68]
# INFO:gluonts.trainer:Epoch[18] Elapsed time 54.139 seconds
# INFO:gluonts.trainer:Epoch[18] Evaluation metric 'epoch_loss'=2.677139
# INFO:gluonts.trainer:Epoch[19] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:55<00:00,  1.11s/it, epoch=20/30, avg_epoch_loss=2.64]
# INFO:gluonts.trainer:Epoch[19] Elapsed time 55.399 seconds
# INFO:gluonts.trainer:Epoch[19] Evaluation metric 'epoch_loss'=2.644702
# INFO:gluonts.trainer:Epoch[20] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:55<00:00,  1.10s/it, epoch=21/30, avg_epoch_loss=2.64]
# INFO:gluonts.trainer:Epoch[20] Elapsed time 55.098 seconds
# INFO:gluonts.trainer:Epoch[20] Evaluation metric 'epoch_loss'=2.640472
# INFO:gluonts.trainer:Epoch[21] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:55<00:00,  1.10s/it, epoch=22/30, avg_epoch_loss=2.61]
# INFO:gluonts.trainer:Epoch[21] Elapsed time 55.252 seconds
# INFO:gluonts.trainer:Epoch[21] Evaluation metric 'epoch_loss'=2.611829
# INFO:gluonts.trainer:Epoch[22] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:55<00:00,  1.12s/it, epoch=23/30, avg_epoch_loss=2.59]
# INFO:gluonts.trainer:Epoch[22] Elapsed time 55.917 seconds
# INFO:gluonts.trainer:Epoch[22] Evaluation metric 'epoch_loss'=2.585127
# INFO:gluonts.trainer:Epoch[23] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:57<00:00,  1.15s/it, epoch=24/30, avg_epoch_loss=2.58]
# INFO:gluonts.trainer:Epoch[23] Elapsed time 57.572 seconds
# INFO:gluonts.trainer:Epoch[23] Evaluation metric 'epoch_loss'=2.576931
# INFO:gluonts.trainer:Epoch[24] Learning rate is 0.001
# 100%|███████████████████| 50/50 [01:05<00:00,  1.30s/it, epoch=25/30, avg_epoch_loss=2.58]
# INFO:gluonts.trainer:Epoch[24] Elapsed time 65.106 seconds
# INFO:gluonts.trainer:Epoch[24] Evaluation metric 'epoch_loss'=2.575724
# INFO:gluonts.trainer:Epoch[25] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:54<00:00,  1.07s/it, epoch=26/30, avg_epoch_loss=2.54]
# INFO:gluonts.trainer:Epoch[25] Elapsed time 54.029 seconds
# INFO:gluonts.trainer:Epoch[25] Evaluation metric 'epoch_loss'=2.536781
# INFO:gluonts.trainer:Epoch[26] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:52<00:00,  1.07s/it, epoch=27/30, avg_epoch_loss=2.55]
# INFO:gluonts.trainer:Epoch[26] Elapsed time 52.926 seconds
# INFO:gluonts.trainer:Epoch[26] Evaluation metric 'epoch_loss'=2.548907
# INFO:gluonts.trainer:Epoch[27] Learning rate is 0.001
# 100%|███████████████████| 50/50 [01:01<00:00,  1.24s/it, epoch=28/30, avg_epoch_loss=2.53]
# INFO:gluonts.trainer:Epoch[27] Elapsed time 61.928 seconds
# INFO:gluonts.trainer:Epoch[27] Evaluation metric 'epoch_loss'=2.527800
# INFO:gluonts.trainer:Epoch[28] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:59<00:00,  1.19s/it, epoch=29/30, avg_epoch_loss=2.51]
# INFO:gluonts.trainer:Epoch[28] Elapsed time 59.749 seconds
# INFO:gluonts.trainer:Epoch[28] Evaluation metric 'epoch_loss'=2.506709
# INFO:gluonts.trainer:Epoch[29] Learning rate is 0.001
# 100%|███████████████████| 50/50 [00:59<00:00,  1.18s/it, epoch=30/30, avg_epoch_loss=2.51]
# INFO:gluonts.trainer:Epoch[29] Elapsed time 59.116 seconds
# INFO:gluonts.trainer:Epoch[29] Evaluation metric 'epoch_loss'=2.511888
# INFO:gluonts.trainer:Loading parameters from best epoch (28)
# INFO:gluonts.trainer:Final loss: 2.5067093420028685 (occurred at epoch 28)
# INFO:gluonts.trainer:End model training
# WARNING:root:You have set `num_workers` to a non zero value, however, currently multiprocessing is not supported on windows and therefore`num_workers will be set to 0.

# %%
plotModel(data_ts_sd_m['Motor speed'], 
          data_ts_cu_m['Current'], 
          data_ts_te_m['Temperature'], 
          data_ts_nm_m['Torque'], 
          sd_gluon_predictions, 
          cu_gluon_predictions, 
          te_gluon_predictions, 
          nm_gluon_predictions, 
          'Amazon Gluon TS', 
          sd_gluon_mse, sd_gluon_mape, sd_gluon_maxerror, 
          cu_gluon_mse, cu_gluon_mape, cu_gluon_maxerror,
          te_gluon_mse, te_gluon_mape, te_gluon_maxerror, 
          nm_gluon_mse, nm_gluon_mape, nm_gluon_maxerror,
          predictive_mode=True)

# %% [markdown]
# ## LSTM

# %%
def get_data(f_dataset, look_back):
    datax = []
    datay = []
    for i in range(len(f_dataset)-look_back-1):
        a = f_dataset[i:(i+look_back), 0]
        datax.append(a)
        datay.append(f_dataset[i+look_back, 0])
    return np.array(datax), np.array(datay)

def lstm(dataset, epochs=20, batch_size=1, activation_lstm='tanh', activation_dense='relu'):
    
    data = np.array(dataset).reshape(-1,1)
    scaler = MinMaxScaler()
    data = scaler.fit_transform(data)
    
    train, test = split(data)
    
    look_back = 1
    x_train, y_train = get_data(train, look_back)
    x_test, y_test = get_data(test, look_back)
    
    x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
    x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)
    
    
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.LSTM(16, activation=activation_lstm, input_shape = (1,1)))
    model.add(tf.keras.layers.Dropout(0.3))

    model.add(tf.keras.layers.Dense(1, activation=activation_dense))

    model.compile(optimizer='adam', loss = 'mean_squared_error') 
    model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size)
    
    y_pred = model.predict(x_test)
    y_pred = scaler.inverse_transform(y_pred)
    
    y_test = np.array(y_test)
    y_test = y_test.reshape(-1,1)
    y_test = scaler.inverse_transform(y_test)

    forecast = pd.DataFrame(y_pred, index=dataset[len(dataset)-len(y_pred):].index)

    mape, evs, maxerror, mae, mse, msle, r2, mpd = quality_metrics(y_test, y_pred)

    return forecast, mape, mse, maxerror

# %%
sd_lstm_predictions, sd_lstm_mape, sd_lstm_mse, sd_lstm_maxerror = lstm(data_ts_sd_m['Motor speed'])
cu_lstm_predictions, cu_lstm_mape, cu_lstm_mse, cu_lstm_maxerror = lstm(data_ts_cu_m['Current'])
te_lstm_predictions, te_lstm_mape, te_lstm_mse, te_lstm_maxerror = lstm(data_ts_te_m['Temperature'])
nm_lstm_predictions, nm_lstm_mape, nm_lstm_mse, nm_lstm_maxerror = lstm(data_ts_nm_m['Torque'])
# Out:
# Train on 1007 samples
# Epoch 1/20
# 1007/1007 [==============================] - ETA: 22:39 - loss: 1.00 - ETA: 1:09 - loss: 0.6896 - ETA: 34s - loss: 0.622 - ETA: 23s - loss: 0.65 - ETA: 18s - loss: 0.60 - ETA: 15s - loss: 0.62 - ETA: 14s - loss: 0.61 - ETA: 13s - loss: 0.60 - ETA: 11s - loss: 0.57 - ETA: 10s - loss: 0.55 - ETA: 9s - loss: 0.5120 - ETA: 8s - loss: 0.483 - ETA: 7s - loss: 0.449 - ETA: 7s - loss: 0.416 - ETA: 6s - loss: 0.388 - ETA: 6s - loss: 0.364 - ETA: 5s - loss: 0.340 - ETA: 5s - loss: 0.322 - ETA: 4s - loss: 0.306 - ETA: 4s - loss: 0.292 - ETA: 4s - loss: 0.280 - ETA: 4s - loss: 0.266 - ETA: 3s - loss: 0.254 - ETA: 3s - loss: 0.244 - ETA: 3s - loss: 0.236 - ETA: 3s - loss: 0.229 - ETA: 3s - loss: 0.222 - ETA: 2s - loss: 0.214 - ETA: 2s - loss: 0.207 - ETA: 2s - loss: 0.201 - ETA: 2s - loss: 0.196 - ETA: 2s - loss: 0.191 - ETA: 2s - loss: 0.186 - ETA: 2s - loss: 0.181 - ETA: 1s - loss: 0.176 - ETA: 1s - loss: 0.172 - ETA: 1s - loss: 0.169 - ETA: 1s - loss: 0.165 - ETA: 1s - loss: 0.162 - ETA: 1s - loss: 0.159 - ETA: 1s - loss: 0.155 - ETA: 1s - loss: 0.152 - ETA: 1s - loss: 0.149 - ETA: 0s - loss: 0.146 - ETA: 0s - loss: 0.143 - ETA: 0s - loss: 0.140 - ETA: 0s - loss: 0.138 - ETA: 0s - loss: 0.136 - ETA: 0s - loss: 0.133 - ETA: 0s - loss: 0.131 - ETA: 0s - loss: 0.130 - ETA: 0s - loss: 0.128 - ETA: 0s - loss: 0.125 - ETA: 0s - loss: 0.124 - ETA: 0s - loss: 0.121 - 4s 4ms/sample - loss: 0.1217
# Epoch 2/20
# 1007/1007 [==============================] - ETA: 4s - loss: 0.099 - ETA: 3s - loss: 0.034 - ETA: 2s - loss: 0.032 - ETA: 2s - loss: 0.029 - ETA: 2s - loss: 0.030 - ETA: 2s - loss: 0.031 - ETA: 2s - loss: 0.029 - ETA: 2s - loss: 0.027 - ETA: 2s - loss: 0.026 - ETA: 2s - loss: 0.025 - ETA: 2s - loss: 0.025 - ETA: 2s - loss: 0.025 - ETA: 2s - loss: 0.024 - ETA: 2s - loss: 0.024 - ETA: 2s - loss: 0.024 - ETA: 2s - loss: 0.023 - ETA: 1s - loss: 0.023 - ETA: 1s - loss: 0.023 - ETA: 1s - loss: 0.023 - ETA: 1s - loss: 0.023 - ETA: 1s - loss: 0.022 - ETA: 1s - loss: 0.022 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.022 - ETA: 1s - loss: 0.022 - ETA: 1s - loss: 0.022 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - 3s 3ms/sample - loss: 0.0195
# Epoch 3/20
# 1007/1007 [==============================] - ETA: 4s - loss: 3.7396e-0 - ETA: 3s - loss: 0.0076    - ETA: 3s - loss: 0.008 - ETA: 3s - loss: 0.009 - ETA: 3s - loss: 0.010 - ETA: 3s - loss: 0.009 - ETA: 3s - loss: 0.010 - ETA: 3s - loss: 0.010 - ETA: 3s - loss: 0.010 - ETA: 3s - loss: 0.010 - ETA: 3s - loss: 0.010 - ETA: 3s - loss: 0.010 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.013 - ETA: 2s - loss: 0.014 - ETA: 2s - loss: 0.013 - ETA: 2s - loss: 0.014 - ETA: 1s - loss: 0.014 - ETA: 1s - loss: 0.014 - ETA: 1s - loss: 0.014 - ETA: 1s - loss: 0.014 - ETA: 1s - loss: 0.015 - ETA: 1s - loss: 0.015 - ETA: 1s - loss: 0.015 - ETA: 1s - loss: 0.015 - ETA: 1s - loss: 0.015 - ETA: 1s - loss: 0.015 - ETA: 1s - loss: 0.015 - ETA: 1s - loss: 0.015 - ETA: 1s - loss: 0.015 - ETA: 1s - loss: 0.015 - ETA: 1s - loss: 0.015 - ETA: 1s - loss: 0.015 - ETA: 1s - loss: 0.015 - ETA: 0s - loss: 0.015 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - ETA: 0s - loss: 0.014 - 3s 3ms/sample - loss: 0.0144
# Epoch 4/20
# 1007/1007 [==============================] - ETA: 6s - loss: 1.6594e-0 - ETA: 3s - loss: 0.0267    - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.013 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 0s - loss: 0.010 - ETA: 0s - loss: 0.010 - ETA: 0s - loss: 0.010 - ETA: 0s - loss: 0.010 - ETA: 0s - loss: 0.010 - ETA: 0s - loss: 0.010 - ETA: 0s - loss: 0.010 - ETA: 0s - loss: 0.010 - ETA: 0s - loss: 0.009 - ETA: 0s - loss: 0.009 - ETA: 0s - loss: 0.009 - ETA: 0s - loss: 0.009 - ETA: 0s - loss: 0.009 - ETA: 0s - loss: 0.009 - ETA: 0s - loss: 0.010 - ETA: 0s - loss: 0.010 - ETA: 0s - loss: 0.009 - ETA: 0s - loss: 0.009 - ETA: 0s - loss: 0.009 - 2s 2ms/sample - loss: 0.0099
# Epoch 5/20
# 1007/1007 [==============================] - ETA: 2s - loss: 7.2413e-0 - ETA: 2s - loss: 0.0034    - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.010 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.009 - ETA: 1s - loss: 0.009 - ETA: 1s - loss: 0.009 - ETA: 1s - loss: 0.009 - ETA: 1s - loss: 0.008 - ETA: 1s - loss: 0.009 - ETA: 1s - loss: 0.009 - ETA: 1s - loss: 0.009 - ETA: 1s - loss: 0.008 - ETA: 1s - loss: 0.008 - ETA: 1s - loss: 0.008 - ETA: 1s - loss: 0.008 - ETA: 1s - loss: 0.008 - ETA: 1s - loss: 0.009 - ETA: 1s - loss: 0.009 - ETA: 1s - loss: 0.008 - ETA: 1s - loss: 0.008 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.009 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.008 - ETA: 0s - loss: 0.008 - 2s 2ms/sample - loss: 0.0084
# Epoch 6/20
# 1007/1007 [==============================] - ETA: 4s - loss: 7.8980e-0 - ETA: 2s - loss: 0.0059    - ETA: 2s - loss: 0.006 - ETA: 2s - loss: 0.006 - ETA: 2s - loss: 0.006 - ETA: 2s - loss: 0.006 - ETA: 2s - loss: 0.006 - ETA: 2s - loss: 0.006 - ETA: 2s - loss: 0.006 - ETA: 2s - loss: 0.006 - ETA: 2s - loss: 0.006 - ETA: 2s - loss: 0.006 - ETA: 2s - loss: 0.006 - ETA: 2s - loss: 0.007 - ETA: 2s - loss: 0.006 - ETA: 2s - loss: 0.007 - ETA: 1s - loss: 0.007 - ETA: 1s - loss: 0.007 - ETA: 1s - loss: 0.007 - ETA: 1s - loss: 0.007 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 1s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - ETA: 0s - loss: 0.006 - 3s 3ms/sample - loss: 0.0067
# Epoch 7/20
# 1007/1007 [==============================] - ETA: 4s - loss: 1.1088e-0 - ETA: 3s - loss: 0.0035    - ETA: 3s - loss: 0.003 - ETA: 3s - loss: 0.003 - ETA: 3s - loss: 0.003 - ETA: 3s - loss: 0.003 - ETA: 3s - loss: 0.003 - ETA: 3s - loss: 0.003 - ETA: 3s - loss: 0.003 - ETA: 3s - loss: 0.004 - ETA: 3s - loss: 0.004 - ETA: 3s - loss: 0.004 - ETA: 3s - loss: 0.004 - ETA: 3s - loss: 0.004 - ETA: 3s - loss: 0.004 - ETA: 3s - loss: 0.004 - ETA: 3s - loss: 0.004 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.004 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - 3s 3ms/sample - loss: 0.0053
# Epoch 8/20
# 1007/1007 [==============================] - ETA: 5s - loss: 4.1379e-0 - ETA: 3s - loss: 0.0057    - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.004 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - ETA: 0s - loss: 0.005 - 2s 2ms/sample - loss: 0.0050
# Epoch 9/20
# 1007/1007 [==============================] - ETA: 3s - loss: 0.008 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.006 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - ETA: 0s - loss: 0.004 - 2s 2ms/sample - loss: 0.0043
# Epoch 10/20
# 1007/1007 [==============================] - ETA: 3s - loss: 0.003 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.006 - ETA: 2s - loss: 0.006 - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.004 - ETA: 1s - loss: 0.005 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.004 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - 2s 2ms/sample - loss: 0.0035
# Epoch 11/20
# 1007/1007 [==============================] - ETA: 2s - loss: 0.011 - ETA: 3s - loss: 0.005 - ETA: 3s - loss: 0.004 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - 3s 3ms/sample - loss: 0.0030
# Epoch 12/20
# 1007/1007 [==============================] - ETA: 3s - loss: 6.6511e-0 - ETA: 2s - loss: 0.0014    - ETA: 2s - loss: 0.005 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.004 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - 3s 3ms/sample - loss: 0.0027
# Epoch 13/20
# 1007/1007 [==============================] - ETA: 3s - loss: 4.5541e-0 - ETA: 3s - loss: 0.0036    - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - 3s 3ms/sample - loss: 0.0023
# Epoch 14/20
# 1007/1007 [==============================] - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 1s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - ETA: 0s - loss: 0.003 - 3s 3ms/sample - loss: 0.0029
# Epoch 15/20
# 1007/1007 [==============================] - ETA: 3s - loss: 1.3724e-0 - ETA: 2s - loss: 0.0020    - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - 3s 3ms/sample - loss: 0.0022
# Epoch 16/20
# 1007/1007 [==============================] - ETA: 3s - loss: 7.4612e-0 - ETA: 2s - loss: 0.0016    - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - 3s 3ms/sample - loss: 0.0022
# Epoch 17/20
# 1007/1007 [==============================] - ETA: 4s - loss: 0.001 - ETA: 2s - loss: 0.002 - ETA: 3s - loss: 0.003 - ETA: 3s - loss: 0.003 - ETA: 3s - loss: 0.002 - ETA: 3s - loss: 0.002 - ETA: 3s - loss: 0.002 - ETA: 3s - loss: 0.002 - ETA: 3s - loss: 0.002 - ETA: 3s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - 3s 3ms/sample - loss: 0.0018
# Epoch 18/20
# 1007/1007 [==============================] - ETA: 3s - loss: 8.0742e-0 - ETA: 2s - loss: 0.0013    - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - ETA: 0s - loss: 0.002 - 3s 3ms/sample - loss: 0.0020
# Epoch 19/20
# 1007/1007 [==============================] - ETA: 2s - loss: 5.7655e-0 - ETA: 2s - loss: 8.6407e-0 - ETA: 2s - loss: 0.0011    - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - 3s 3ms/sample - loss: 0.0017
# Epoch 20/20
# 1007/1007 [==============================] - ETA: 4s - loss: 2.4217e-0 - ETA: 2s - loss: 0.0018    - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.003 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 2s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.002 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 1s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - ETA: 0s - loss: 0.001 - 2s 2ms/sample - loss: 0.0018
# Train on 1007 samples
# Epoch 1/20
# 1007/1007 [==============================] - ETA: 26:59 - loss: 0.08 - ETA: 1:14 - loss: 0.2113 - ETA: 40s - loss: 0.209 - ETA: 26s - loss: 0.21 - ETA: 21s - loss: 0.19 - ETA: 16s - loss: 0.18 - ETA: 14s - loss: 0.16 - ETA: 12s - loss: 0.14 - ETA: 10s - loss: 0.13 - ETA: 9s - loss: 0.1190 - ETA: 8s - loss: 0.109 - ETA: 7s - loss: 0.102 - ETA: 7s - loss: 0.095 - ETA: 6s - loss: 0.089 - ETA: 5s - loss: 0.084 - ETA: 5s - loss: 0.080 - ETA: 5s - loss: 0.076 - ETA: 4s - loss: 0.073 - ETA: 4s - loss: 0.070 - ETA: 4s - loss: 0.067 - ETA: 3s - loss: 0.065 - ETA: 3s - loss: 0.063 - ETA: 3s - loss: 0.062 - ETA: 3s - loss: 0.061 - ETA: 3s - loss: 0.059 - ETA: 2s - loss: 0.058 - ETA: 2s - loss: 0.057 - ETA: 2s - loss: 0.055 - ETA: 2s - loss: 0.054 - ETA: 2s - loss: 0.053 - ETA: 2s - loss: 0.051 - ETA: 2s - loss: 0.050 - ETA: 1s - loss: 0.049 - ETA: 1s - loss: 0.049 - ETA: 1s - loss: 0.048 - ETA: 1s - loss: 0.047 - ETA: 1s - loss: 0.046 - ETA: 1s - loss: 0.045 - ETA: 1s - loss: 0.045 - ETA: 1s - loss: 0.044 - ETA: 0s - loss: 0.044 - ETA: 0s - loss: 0.043 - ETA: 0s - loss: 0.043 - ETA: 0s - loss: 0.042 - ETA: 0s - loss: 0.041 - ETA: 0s - loss: 0.041 - ETA: 0s - loss: 0.041 - ETA: 0s - loss: 0.041 - ETA: 0s - loss: 0.040 - ETA: 0s - loss: 0.040 - ETA: 0s - loss: 0.039 - 4s 4ms/sample - loss: 0.0396
# Epoch 2/20
# 1007/1007 [==============================] - ETA: 3s - loss: 6.8486e-0 - ETA: 2s - loss: 0.0152    - ETA: 2s - loss: 0.014 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.021 - ETA: 0s - loss: 0.021 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.021 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - 3s 3ms/sample - loss: 0.0205
# Epoch 3/20
# 1007/1007 [==============================] - ETA: 3s - loss: 0.023 - ETA: 2s - loss: 0.025 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.021 - ETA: 2s - loss: 0.021 - ETA: 2s - loss: 0.022 - ETA: 2s - loss: 0.021 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.021 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - 2s 2ms/sample - loss: 0.0202
# Epoch 4/20
# 1007/1007 [==============================] - ETA: 5s - loss: 0.011 - ETA: 3s - loss: 0.016 - ETA: 2s - loss: 0.024 - ETA: 2s - loss: 0.026 - ETA: 2s - loss: 0.023 - ETA: 2s - loss: 0.023 - ETA: 2s - loss: 0.022 - ETA: 2s - loss: 0.021 - ETA: 2s - loss: 0.021 - ETA: 2s - loss: 0.022 - ETA: 2s - loss: 0.021 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.019 - 3s 2ms/sample - loss: 0.0198
# Epoch 5/20
# 1007/1007 [==============================] - ETA: 4s - loss: 3.2039e-0 - ETA: 2s - loss: 0.0201    - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.015 - ETA: 2s - loss: 0.016 - ETA: 1s - loss: 0.016 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - 2s 2ms/sample - loss: 0.0197
# Epoch 6/20
# 1007/1007 [==============================] - ETA: 3s - loss: 0.015 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - 3s 3ms/sample - loss: 0.0195
# Epoch 7/20
# 1007/1007 [==============================] - ETA: 6s - loss: 0.013 - ETA: 3s - loss: 0.015 - ETA: 3s - loss: 0.013 - ETA: 3s - loss: 0.012 - ETA: 3s - loss: 0.014 - ETA: 3s - loss: 0.013 - ETA: 3s - loss: 0.015 - ETA: 3s - loss: 0.015 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.021 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.020 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - 3s 3ms/sample - loss: 0.0197
# Epoch 8/20
# 1007/1007 [==============================] - ETA: 3s - loss: 0.006 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.014 - ETA: 2s - loss: 0.015 - ETA: 2s - loss: 0.014 - ETA: 2s - loss: 0.015 - ETA: 2s - loss: 0.014 - ETA: 2s - loss: 0.014 - ETA: 2s - loss: 0.014 - ETA: 2s - loss: 0.015 - ETA: 2s - loss: 0.015 - ETA: 2s - loss: 0.015 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - 3s 3ms/sample - loss: 0.0193
# Epoch 9/20
# 1007/1007 [==============================] - ETA: 3s - loss: 0.016 - ETA: 3s - loss: 0.013 - ETA: 3s - loss: 0.022 - ETA: 3s - loss: 0.022 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.023 - ETA: 2s - loss: 0.022 - ETA: 2s - loss: 0.021 - ETA: 2s - loss: 0.021 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.019 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - 4s 4ms/sample - loss: 0.0188
# Epoch 10/20
# 1007/1007 [==============================] - ETA: 5s - loss: 0.013 - ETA: 4s - loss: 0.017 - ETA: 3s - loss: 0.021 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - 3s 3ms/sample - loss: 0.0191
# Epoch 11/20
# 1007/1007 [==============================] - ETA: 3s - loss: 0.001 - ETA: 2s - loss: 0.010 - ETA: 2s - loss: 0.014 - ETA: 2s - loss: 0.015 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.015 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - 3s 3ms/sample - loss: 0.0189
# Epoch 12/20
# 1007/1007 [==============================] - ETA: 2s - loss: 0.001 - ETA: 2s - loss: 0.009 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.013 - ETA: 2s - loss: 0.013 - ETA: 2s - loss: 0.014 - ETA: 2s - loss: 0.014 - ETA: 2s - loss: 0.015 - ETA: 2s - loss: 0.015 - ETA: 2s - loss: 0.014 - ETA: 2s - loss: 0.015 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.017 - ETA: 1s - loss: 0.016 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.016 - ETA: 1s - loss: 0.016 - ETA: 1s - loss: 0.016 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.018 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - 3s 3ms/sample - loss: 0.0189
# Epoch 13/20
# 1007/1007 [==============================] - ETA: 3s - loss: 0.001 - ETA: 2s - loss: 0.015 - ETA: 2s - loss: 0.013 - ETA: 2s - loss: 0.014 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.019 - ETA: 2s - loss: 0.018 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.020 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 1s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - 3s 3ms/sample - loss: 0.0192
# Epoch 14/20
# 1007/1007 [==============================] - ETA: 4s - loss: 0.022 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.020 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 1s - loss: 0.017 - ETA: 0s - loss: 0.017 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.017 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.018 - ETA: 0s - loss: 0.019 - ETA: 0s - loss: 0.019 - 3s 3ms/sample - loss: 0.0189
# Epoch 15/20
# ...
# Epoch 8/20
# 1007/1007 [==============================] - ETA: 3s - loss: 0.008 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.014 - ETA: 2s - loss: 0.013 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.013 - ETA: 0s - loss: 0.013 - ETA: 0s - loss: 0.013 - ETA: 0s - loss: 0.013 - ETA: 0s - loss: 0.013 - ETA: 0s - loss: 0.013 - ETA: 0s - loss: 0.013 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - 2s 2ms/sample - loss: 0.0125
# Epoch 9/20
# 1007/1007 [==============================] - ETA: 4s - loss: 0.018 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.016 - ETA: 2s - loss: 0.015 - ETA: 2s - loss: 0.014 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - 2s 2ms/sample - loss: 0.0123
# Epoch 10/20
# 1007/1007 [==============================] - ETA: 4s - loss: 0.002 - ETA: 2s - loss: 0.009 - ETA: 2s - loss: 0.009 - ETA: 2s - loss: 0.008 - ETA: 2s - loss: 0.008 - ETA: 2s - loss: 0.009 - ETA: 2s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - 2s 2ms/sample - loss: 0.0125
# Epoch 11/20
# 1007/1007 [==============================] - ETA: 3s - loss: 0.055 - ETA: 2s - loss: 0.015 - ETA: 2s - loss: 0.013 - ETA: 2s - loss: 0.013 - ETA: 2s - loss: 0.010 - ETA: 2s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - 2s 2ms/sample - loss: 0.0126
# Epoch 12/20
# 1007/1007 [==============================] - ETA: 3s - loss: 0.011 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.013 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.011 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - 2s 2ms/sample - loss: 0.0124
# Epoch 13/20
# 1007/1007 [==============================] - ETA: 3s - loss: 7.2385e-0 - ETA: 2s - loss: 0.0127    - ETA: 2s - loss: 0.013 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.013 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.010 - ETA: 2s - loss: 0.010 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.013 - ETA: 0s - loss: 0.013 - ETA: 0s - loss: 0.013 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - 3s 3ms/sample - loss: 0.0124
# Epoch 14/20
# 1007/1007 [==============================] - ETA: 4s - loss: 0.048 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.010 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.013 - ETA: 2s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - 2s 2ms/sample - loss: 0.0125
# Epoch 15/20
# 1007/1007 [==============================] - ETA: 3s - loss: 0.009 - ETA: 2s - loss: 0.010 - ETA: 2s - loss: 0.010 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.013 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - 2s 2ms/sample - loss: 0.0125
# Epoch 16/20
# 1007/1007 [==============================] - ETA: 4s - loss: 0.003 - ETA: 2s - loss: 0.018 - ETA: 2s - loss: 0.017 - ETA: 2s - loss: 0.015 - ETA: 2s - loss: 0.014 - ETA: 2s - loss: 0.013 - ETA: 2s - loss: 0.012 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.013 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - 2s 2ms/sample - loss: 0.0126
# Epoch 17/20
# 1007/1007 [==============================] - ETA: 3s - loss: 3.1619e-0 - ETA: 2s - loss: 0.0153    - ETA: 2s - loss: 0.014 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - 2s 2ms/sample - loss: 0.0124
# Epoch 18/20
# 1007/1007 [==============================] - ETA: 4s - loss: 0.002 - ETA: 2s - loss: 0.006 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.010 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.011 - ETA: 0s - loss: 0.011 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - 3s 3ms/sample - loss: 0.0122
# Epoch 19/20
# 1007/1007 [==============================] - ETA: 4s - loss: 0.013 - ETA: 2s - loss: 0.014 - ETA: 3s - loss: 0.012 - ETA: 2s - loss: 0.010 - ETA: 2s - loss: 0.010 - ETA: 2s - loss: 0.010 - ETA: 2s - loss: 0.010 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.012 - ETA: 2s - loss: 0.011 - ETA: 2s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.013 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 1s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - 3s 3ms/sample - loss: 0.0123
# Epoch 20/20
# 1007/1007 [==============================] - ETA: 3s - loss: 1.3914e-0 - ETA: 2s - loss: 0.0091    - ETA: 2s - loss: 0.010 - ETA: 2s - loss: 0.010 - ETA: 2s - loss: 0.008 - ETA: 2s - loss: 0.008 - ETA: 2s - loss: 0.009 - ETA: 2s - loss: 0.009 - ETA: 2s - loss: 0.009 - ETA: 2s - loss: 0.009 - ETA: 2s - loss: 0.009 - ETA: 2s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.010 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 1s - loss: 0.011 - ETA: 0s - loss: 0.011 - ETA: 0s - loss: 0.011 - ETA: 0s - loss: 0.011 - ETA: 0s - loss: 0.011 - ETA: 0s - loss: 0.011 - ETA: 0s - loss: 0.011 - ETA: 0s - loss: 0.011 - ETA: 0s - loss: 0.011 - ETA: 0s - loss: 0.011 - ETA: 0s - loss: 0.011 - ETA: 0s - loss: 0.011 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.011 - ETA: 0s - loss: 0.011 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - ETA: 0s - loss: 0.012 - 2s 2ms/sample - loss: 0.0123

# %%
plotModel(data_ts_sd_m['Motor speed'], 
          data_ts_cu_m['Current'], 
          data_ts_te_m['Temperature'], 
          data_ts_nm_m['Torque'], 
          sd_lstm_predictions, 
          cu_lstm_predictions, 
          te_lstm_predictions, 
          nm_lstm_predictions, 
          'LSTM', 
          sd_lstm_mse, sd_lstm_mape, sd_lstm_maxerror, 
          cu_lstm_mse, cu_lstm_mape, cu_lstm_maxerror,
          te_lstm_mse, te_lstm_mape, te_lstm_maxerror, 
          nm_lstm_mse, nm_lstm_mape, nm_lstm_maxerror,
          predictive_mode=True)
